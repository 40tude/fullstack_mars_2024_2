# %% [markdown]
# # Sentiment Analysis with RNN
#
# Now that we learned how to build and train recurrent neural networks, we will attempt to use them for sentiment analysis, thus combining everything that we have learned this far.

# %% [markdown]
# ## Data Preprocessing
#
# This part will be the same as previous axercises but try and do it without the help of previous solutions, this way you will understand much better how to work the different steps of the process.
#
# ### Import Data
#
# 1. Import the following libraries:
#
# * tensorflow
# * pathlib
# * pandas
# * os
# * io

# %%
# Import Tensorflow & Pathlib librairies
import tensorflow as tf 
import pathlib 
import pandas as pd 
import os
import io
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. Copy the link below and read the file it contains with `pandas`.
#
# * https://go.aws/314bBDq

# %%
# Import dataset with Pandas 
dataset = pd.read_csv("https://go.aws/314bBDq", error_bad_lines=False, encoding="utf-8")
dataset.head()
# Out:
#                             user_id  ... review_nb_words
# 0  efb62a167fee5cf3678b24427de8e31f  ...              19
# 1  e3be4f9c9e0b9572bfb2a5f88497bb14  ...               0
# 2  1b8e5760162d867e9b9ca80f645bdc60  ...               4
# 3  fa330e5891a1bb486c3e9bf95c098726  ...               0
# 4  c1a693206aee1a2412d4bd9e45b80ec5  ...               0
#
# [5 rows x 12 columns]

# %% [markdown]
# 3. We will need the reviews in French. Filter the reviews so that they are in the right language. For this you need to find a column that gives you that information.

# %%
# Taking only french reviews
french_reviews = dataset[dataset.review_lang == "french"]
french_reviews.head()
# Out:
#                              user_id  ... review_nb_words
# 0   efb62a167fee5cf3678b24427de8e31f  ...              19
# 2   1b8e5760162d867e9b9ca80f645bdc60  ...               4
# 11  726b1a3e2664e8b075129bcd643dbf56  ...              25
# 12  8a71763fbb3da7436b957681b24cc404  ...               1
# 23  ce7abd7798ee036d667c0ad84b85daa7  ...              23
#
# [5 rows x 12 columns]

# %% [markdown]
# 4. Keep only the `review_format` & `stars` columns.

# %%
# Let's take the columns we're interested in 
french_reviews = french_reviews[["review_format", "stars"]]
french_reviews.head()
# Out:
#                                         review_format  stars
# 0   génial  fabuleux  exceptionnel   j aimerais qu...      5
# 2                    toujours aussi magic  féerique        5
# 11  en vacances en région parisienne nous nous som...      2
# 12                     tropbeaufinalpleinlesyeuxoreil      5
# 23  l univers disney reste merveilleux  toutefois ...      4

# %% [markdown]
# ### Preprocessing
#
# We will now go through a preprocessing phase. The goal is to clean up the character strings and encode the words so they are represented as integers.

# %% [markdown]
# 1. Use the command: `!python -m spacy download fr_core_news_sm` to download all language elements related to the French language

# %%
# !python -m spacy download fr_core_news_sm -q
# Out:
#      |████████████████████████████████| 14.7 MB 5.5 MB/s
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')

# %% [markdown]
# 2. Load now `fr_core_news_sm`

# %%
# Import Spacy and french initialisation
import fr_core_news_sm
nlp = fr_core_news_sm.load()

# %% [markdown]
# 3. Import the french STOP_WORDS

# %%
# Import Stop words 
from spacy.lang.fr.stop_words import STOP_WORDS

# %% [markdown]
# 4. You will now have to clean our texts in order to prepare them for training.
# Let's do this in three different steps :
#  * using the command `str.isalnum` remove all characters from your strings that are not alphanumeric except for whitespaces.
#  * using `str.replace`, `str.lower` and `str.strip` replace double whitespaces with single whitespaces, convert all characters to lowercase and trim starting and finishing whitespaces.
#  * using spacy, replace all tokens in your texts with `lemma_` and remove all the stop words.

# %%
### 

# DO NOT RUN THIS COMMAND (TAKES TIME)
# rather explain it and import the cleaned dataset in the next cell

###
french_reviews["review_format_clean"] = french_reviews["review_format"].apply(lambda x:''.join(ch for ch in x if ch.isalnum() or ch==" "))
french_reviews["review_format_clean"] = french_reviews["review_format_clean"].apply(lambda x: x.replace(" +"," ").lower().strip())
french_reviews["review_format_clean"] = french_reviews["review_format_clean"].apply(lambda x: " ".join([token.lemma_ for token in nlp(x) if (token.lemma_ not in STOP_WORDS) & (token.text not in STOP_WORDS)]))

french_reviews
# Out:
#                                             review_format  ...                                review_format_clean
# 0       génial  fabuleux  exceptionnel   j aimerais qu...  ...  génial   fabuleu   exceptionnel    j aimerai w...
# 2                        toujours aussi magic  féerique    ...                                   magic   féerique
# 11      en vacances en région parisienne nous nous som...  ...  vacance région parisien décider visiter parc r...
# 12                         tropbeaufinalpleinlesyeuxoreil  ...                     tropbeaufinalpleinlesyeuxoreil
# 23      l univers disney reste merveilleux  toutefois ...  ...  l univers disney merveilleux   regrette qu fal...
# ...                                                   ...  ...                                                ...
# 295057  toujours aussi magique même si à la fin du séj...  ...                      magique fin séjour rotule lol
# 295549  séjour au top    mes enfants les plus heureux ...  ...  séjour top     enfant heureux vouloir voir per...
# 298475                   magnifique un monde parfait  lt   ...                     magnifique monde parfaire   lt
# 298832  oui j ai aimé car j adore disney et tout ce qu...  ...  oui j aimer j adore disney touche univers     ...
# 299402  je vais à disney minimum  fois par saison car ...  ...  disney minimum   fois saison magique printemps...
#
# [8474 rows x 3 columns]

# %% [markdown]
# 5. Using `tf.keras.preprocessing.text.Tokenizer` [Tokenizer](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer), process to encoding all the reviews (be careful, some reviews might have been entirely erased, try and understand why, remove those reviews)
#
# When instanciating the tokenizer, make sure you set it up to keep only the 1000 most common words.

# %%
#french_reviews.to_csv("french_review_clean.csv", index=False)

# %%
french_reviews = pd.read_csv("https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/M08-DeepLearning/NLP/french_review_clean.csv")

# %%
mask = french_reviews["review_format_clean"].isna()==False
french_reviews = french_reviews[mask]

# %%
import numpy as np
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=1000) # instanciate the tokenizer
tokenizer.fit_on_texts(french_reviews["review_format_clean"])
french_reviews["review_encoded"] = tokenizer.texts_to_sequences(french_reviews.review_format_clean)
french_reviews["len_review"] = french_reviews["review_encoded"].apply(lambda x: len(x))
french_reviews = french_reviews[french_reviews["len_review"]!=0]

# %% [markdown]
# 6. Tensorflow is incapable as of now to create a tensor dataset based on lists of different lengths, we will have to store all of our encoded texts into a single numpy array before creating the tensorflow dataset.
# Not all our sequences are the same length, this is where the `tf.keras.preprocessing.sequence.pad_sequences` comes in handy, it will add zero padding at the beginning (`padding="pre"`) or at the end (`padding="post"`) of your sequences so they all have equal length.
# Pad the sequences.

# %%
reviews_pad = tf.keras.preprocessing.sequence.pad_sequences(french_reviews.review_encoded, padding="post")

# %% [markdown]
# 7. Now that your sequences are padded, create the tensor dataset, we are going to start by treating the `stars` variable as categorical, so we need to represent it on scale of 0 to 4 (because of the way the `SparseCategoricalCrossentropy` works).
# Form the full tensor dataset with these constraints in mind.

# %%
full_ds = tf.data.Dataset.from_tensor_slices((reviews_pad, french_reviews.stars.values-1))

# %% [markdown]
# 8. Do a `train_test_split` of your data (keep about 70% in the train). For this you may use the `.take` and `.skip` methods on the tensorflow dataset.
# Once you have done this you may use `.shuffle` on the train set, and `.batch`on both sets to organise them by batches of 64 observations.
#
# * [take documentation](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#take)
#
# * [skip documentation](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#skip)
#
# * [shuffle documentation](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle)
#
# * [batch documentation](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#batch)

# %%
# Train Test Split
TAKE_SIZE = int(0.7*french_reviews.shape[0])

train_data = full_ds.take(TAKE_SIZE).shuffle(TAKE_SIZE)
train_data = train_data.batch(64)

test_data = full_ds.skip(TAKE_SIZE)
test_data = test_data.batch(64)

# %% [markdown]
# 9. Look at a batch of data

# %%
 # Regardons un batch 
for review, star in train_data.take(1):
  print(review, star)
# Out:
# tf.Tensor(
# [[ 37  24 487 ...   0   0   0]
#  [162 169   3 ...   0   0   0]
#  [  8 278  72 ...   0   0   0]
#  ...
#  [ 42  37  25 ...   0   0   0]
#  [612  16   8 ...   0   0   0]
#  [  1  10   1 ...   0   0   0]], shape=(64, 179), dtype=int32) tf.Tensor(
# [4 4 3 3 3 4 2 3 4 2 1 4 0 3 4 2 4 3 4 3 4 4 2 3 4 4 4 2 4 0 4 4 3 4 1 4 4
#  2 4 3 3 2 1 3 0 4 2 4 4 0 4 0 4 0 4 4 4 3 4 2 4 4 4 1], shape=(64,), dtype=int64)

# %% [markdown]
# ## Classification Modeling
#
# We'll start by treating the sentiment analysis as a classification problem (this will affect the last layer and the choice of loss function and metric).

# %% [markdown]
# ### SimpleRNN

# %% [markdown]
# 1. Follow a similar architecture to the one we used in the code embedding demonstration.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model = tf.keras.Sequential([
                  # Word Embedding layer           
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  # Gobal average pooling
                  SimpleRNN(units=64, return_sequences=True), # maintains the sequential nature
                  SimpleRNN(units=32, return_sequences=False), # returns the last output
                  # Dense layers once the data is flat
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  # output layer with as many neurons as the number of classes
                  # for the target variable and softmax activation
                  Dense(5, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 179, 64)           657600
# _________________________________________________________________
# simple_rnn_6 (SimpleRNN)     (None, 179, 64)           8256
# _________________________________________________________________
# simple_rnn_7 (SimpleRNN)     (None, 32)                3104
# _________________________________________________________________
# dense_15 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 45
# =================================================================
# Total params: 669,669
# Trainable params: 669,669
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer= tf.keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %% [markdown]
# 3. Using the pandas function `.value_counts` create a dictionnary that assigns to each value of the target variable a weight that is inversely proportionnal to their frequency in the dataset.

# %%
(french_reviews["stars"]-1).value_counts()
# Out:
# 4    4845
# 3    1535
# 2    1008
# 0     558
# 1     486
# Name: stars, dtype: int64

# %%
weights = 1/(french_reviews["stars"]-1).value_counts()
weights = weights * len(french_reviews)/5
weights = {index : values for index , values in zip(weights.index,weights.values)}
weights
# Out:
# {0: 3.022222222222222,
#  1: 3.4699588477366254,
#  2: 1.6730158730158728,
#  3: 1.0986319218241043,
#  4: 0.3480701754385965}

# %% [markdown]
# 4. Fit your model on 20 epochs with weights to penalize too frequent notes.

# %%
# Model training 
model.fit(train_data,
          epochs=20, 
          validation_data=test_data,
          class_weight=weights)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 56s 581ms/step - loss: 1.6607 - sparse_categorical_accuracy: 0.1484 - val_loss: 1.6284 - val_sparse_categorical_accuracy: 0.0668
# Epoch 2/20
# 93/93 [==============================] - 54s 579ms/step - loss: 1.6569 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6429 - val_sparse_categorical_accuracy: 0.0668
# Epoch 3/20
# 93/93 [==============================] - 53s 569ms/step - loss: 1.6552 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6548 - val_sparse_categorical_accuracy: 0.0668
# Epoch 4/20
# 93/93 [==============================] - 51s 545ms/step - loss: 1.6543 - sparse_categorical_accuracy: 0.1423 - val_loss: 1.6633 - val_sparse_categorical_accuracy: 0.0668
# Epoch 5/20
# 93/93 [==============================] - 51s 543ms/step - loss: 1.6540 - sparse_categorical_accuracy: 0.1471 - val_loss: 1.6658 - val_sparse_categorical_accuracy: 0.0668
# Epoch 6/20
# 93/93 [==============================] - 52s 555ms/step - loss: 1.6536 - sparse_categorical_accuracy: 0.1506 - val_loss: 1.6712 - val_sparse_categorical_accuracy: 0.0668
# Epoch 7/20
# 93/93 [==============================] - 52s 558ms/step - loss: 1.6533 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6732 - val_sparse_categorical_accuracy: 0.0668
# Epoch 8/20
# 93/93 [==============================] - 51s 547ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6762 - val_sparse_categorical_accuracy: 0.0668
# Epoch 9/20
# 93/93 [==============================] - 52s 557ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6767 - val_sparse_categorical_accuracy: 0.0668
# Epoch 10/20
# 93/93 [==============================] - 51s 551ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6767 - val_sparse_categorical_accuracy: 0.0668
# Epoch 11/20
# 93/93 [==============================] - 53s 573ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6748 - val_sparse_categorical_accuracy: 0.0668
# Epoch 12/20
# 93/93 [==============================] - 52s 561ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6754 - val_sparse_categorical_accuracy: 0.0668
# Epoch 13/20
# 93/93 [==============================] - 52s 557ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6735 - val_sparse_categorical_accuracy: 0.0668
# Epoch 14/20
# 93/93 [==============================] - 52s 564ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6757 - val_sparse_categorical_accuracy: 0.0668
# Epoch 15/20
# 93/93 [==============================] - 52s 560ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6760 - val_sparse_categorical_accuracy: 0.0668
# Epoch 16/20
# 93/93 [==============================] - 52s 555ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6755 - val_sparse_categorical_accuracy: 0.0668
# Epoch 17/20
# 93/93 [==============================] - 53s 570ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6755 - val_sparse_categorical_accuracy: 0.0668
# Epoch 18/20
# 93/93 [==============================] - 52s 556ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6765 - val_sparse_categorical_accuracy: 0.0668
# Epoch 19/20
# 93/93 [==============================] - 51s 552ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6769 - val_sparse_categorical_accuracy: 0.0668
# Epoch 20/20
# 93/93 [==============================] - 51s 546ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6778 - val_sparse_categorical_accuracy: 0.0668

# %% [markdown]
# 5. Save your model, dowload it and upload it to your S3 in order to be able to retrieve it without having to train it again later on.

# %%
model.save("model_simpleRNN.h5")

# %% [markdown]
# 6. Import the `json` library and save the model history dictionnary (make sure it's a dictionary). Dowload it and save it to your S3.

# %%
import json
json.dump(model.history.history, open("/content/simpleRNN_history.json", 'w'))

# %% [markdown]
# ### GRU
#
# 1. Create an object named `model_gru` by replacing the `SimpleRNN` layers by `GRU` layers and replicate the same steps.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model_gru = tf.keras.Sequential([
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  GRU(units=64, return_sequences=True), # maintains the sequential nature
                  GRU(units=32, return_sequences=False), # returns the last output
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  Dense(5, activation="softmax")
])

# %%
model_gru.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 179, 64)           657600
# _________________________________________________________________
# gru_4 (GRU)                  (None, 179, 64)           24960
# _________________________________________________________________
# gru_5 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_20 (Dense)             (None, 5)                 45
# =================================================================
# Total params: 692,677
# Trainable params: 692,677
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer= tf.keras.optimizers.Adam()

model_gru.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
model_gru.fit(train_data,
              epochs=20, 
              validation_data=test_data,
              class_weight=weights)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 12s 90ms/step - loss: 1.6593 - sparse_categorical_accuracy: 0.1159 - val_loss: 1.6536 - val_sparse_categorical_accuracy: 0.0668
# Epoch 2/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6547 - sparse_categorical_accuracy: 0.1450 - val_loss: 1.6761 - val_sparse_categorical_accuracy: 0.0668
# Epoch 3/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6541 - sparse_categorical_accuracy: 0.1669 - val_loss: 1.6650 - val_sparse_categorical_accuracy: 0.1150
# Epoch 4/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6541 - sparse_categorical_accuracy: 0.1842 - val_loss: 1.6748 - val_sparse_categorical_accuracy: 0.0668
# Epoch 5/20
# 93/93 [==============================] - 8s 81ms/step - loss: 1.6538 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6810 - val_sparse_categorical_accuracy: 0.0668
# Epoch 6/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6535 - sparse_categorical_accuracy: 0.1589 - val_loss: 1.6815 - val_sparse_categorical_accuracy: 0.0668
# Epoch 7/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6534 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6904 - val_sparse_categorical_accuracy: 0.0668
# Epoch 8/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6541 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6785 - val_sparse_categorical_accuracy: 0.0668
# Epoch 9/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6536 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6646 - val_sparse_categorical_accuracy: 0.0668
# Epoch 10/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6535 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6900 - val_sparse_categorical_accuracy: 0.0668
# Epoch 11/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6535 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6767 - val_sparse_categorical_accuracy: 0.0668
# Epoch 12/20
# 93/93 [==============================] - 8s 81ms/step - loss: 1.6536 - sparse_categorical_accuracy: 0.1469 - val_loss: 1.6801 - val_sparse_categorical_accuracy: 0.0668
# Epoch 13/20
# 93/93 [==============================] - 8s 81ms/step - loss: 1.6537 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6731 - val_sparse_categorical_accuracy: 0.0668
# Epoch 14/20
# 93/93 [==============================] - 7s 80ms/step - loss: 1.6533 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6673 - val_sparse_categorical_accuracy: 0.0668
# Epoch 15/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6535 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6812 - val_sparse_categorical_accuracy: 0.0668
# Epoch 16/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6534 - sparse_categorical_accuracy: 0.1610 - val_loss: 1.6743 - val_sparse_categorical_accuracy: 0.0668
# Epoch 17/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6534 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6823 - val_sparse_categorical_accuracy: 0.0668
# Epoch 18/20
# 93/93 [==============================] - 7s 80ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6789 - val_sparse_categorical_accuracy: 0.0668
# Epoch 19/20
# 93/93 [==============================] - 8s 81ms/step - loss: 1.6532 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6695 - val_sparse_categorical_accuracy: 0.0668
# Epoch 20/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6738 - val_sparse_categorical_accuracy: 0.0668

# %%
model_gru.save("model_gru.h5")

# %%
import json
json.dump(model_gru.history.history, open("/content/GRU_history.json", 'w'))

# %% [markdown]
# ### LSTM
#
# 1. Create an object named `model_lstm` by replacing the `SimpleRNN` layers by `LSTM` layers and replicate the same steps.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model_lstm = tf.keras.Sequential([
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  LSTM(units=64, return_sequences=True), # maintains the sequential nature
                  LSTM(units=32, return_sequences=False), # returns the last output
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  Dense(5, activation="softmax", name="last")
])

# %%
model_lstm.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 179, 64)           657600
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 179, 64)           33024
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_21 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 136
# _________________________________________________________________
# last (Dense)                 (None, 5)                 45
# =================================================================
# Total params: 703,749
# Trainable params: 703,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer= tf.keras.optimizers.Adam()

model_lstm.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
model_lstm.fit(train_data,
              epochs=20, 
              validation_data=test_data,
               class_weight=weights)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 12s 96ms/step - loss: 1.6593 - sparse_categorical_accuracy: 0.1815 - val_loss: 1.6371 - val_sparse_categorical_accuracy: 0.1150
# Epoch 2/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6551 - sparse_categorical_accuracy: 0.2109 - val_loss: 1.6635 - val_sparse_categorical_accuracy: 0.1150
# Epoch 3/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.6541 - sparse_categorical_accuracy: 0.1764 - val_loss: 1.6864 - val_sparse_categorical_accuracy: 0.1150
# Epoch 4/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6536 - sparse_categorical_accuracy: 0.1852 - val_loss: 1.6738 - val_sparse_categorical_accuracy: 0.1150
# Epoch 5/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6542 - sparse_categorical_accuracy: 0.1854 - val_loss: 1.6751 - val_sparse_categorical_accuracy: 0.0668
# Epoch 6/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6537 - sparse_categorical_accuracy: 0.1422 - val_loss: 1.6829 - val_sparse_categorical_accuracy: 0.0668
# Epoch 7/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.6534 - sparse_categorical_accuracy: 0.1423 - val_loss: 1.6771 - val_sparse_categorical_accuracy: 0.0668
# Epoch 8/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6531 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6760 - val_sparse_categorical_accuracy: 0.0668
# Epoch 9/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6523 - sparse_categorical_accuracy: 0.1423 - val_loss: 1.6824 - val_sparse_categorical_accuracy: 0.0668
# Epoch 10/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6529 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6676 - val_sparse_categorical_accuracy: 0.0668
# Epoch 11/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.6520 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6779 - val_sparse_categorical_accuracy: 0.0668
# Epoch 12/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.6516 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6735 - val_sparse_categorical_accuracy: 0.0668
# Epoch 13/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6515 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6854 - val_sparse_categorical_accuracy: 0.0668
# Epoch 14/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6516 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6776 - val_sparse_categorical_accuracy: 0.0668
# Epoch 15/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6515 - sparse_categorical_accuracy: 0.1423 - val_loss: 1.6734 - val_sparse_categorical_accuracy: 0.0668
# Epoch 16/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6514 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6791 - val_sparse_categorical_accuracy: 0.0668
# Epoch 17/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.6515 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6731 - val_sparse_categorical_accuracy: 0.0668
# Epoch 18/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6515 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6779 - val_sparse_categorical_accuracy: 0.0668
# Epoch 19/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6518 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6779 - val_sparse_categorical_accuracy: 0.0668
# Epoch 20/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.6517 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.6786 - val_sparse_categorical_accuracy: 0.0668

# %%
model_lstm.save("model_lstm.h5")

# %%
import json
json.dump(model_lstm.history.history, open("/content/LSTM_history.json", 'w'))

# %% [markdown]
# ## Classification Evaluation
#
# This part will focus on visualizing the training process and interpreting the results for our predictive models.

# %% [markdown]
# ### SimpleRNN

# %% [markdown]
# 1. Create a graph showing your loss and validation loss in relation to the number of epochs for the simpleRNN model.

# %%
tf.keras.utils.get_file("/content/model_simpleRNN.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_simpleRNN.h5")
# Out:
# '/content/model_simpleRNN.h5'

# %%
tf.keras.utils.get_file("/content/simpleRNN_history.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/simpleRNN_history.json")
# Out:
# '/content/simpleRNN_history.json'

# %%
simpleRNN_history = json.load(open("/content/simpleRNN_history.json", 'r'))

# %%
model_simpleRNN = tf.keras.models.load_model("/content/model_simpleRNN.h5")

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=simpleRNN_history["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=simpleRNN_history["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="49e81ab7-a83f-484d-abb7-69181ab0170d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49e81ab7-a83f-484d-abb7-69181ab0170d")) {
#                     Plotly.newPlot(
#                         '49e81ab7-a83f-484d-abb7-69181ab0170d',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [1.660691738128662, 1.6568922996520996, 1.655206561088562, 1.6542850732803345, 1.6539671421051025, 1.6536312103271484, 1.6533180475234985, 1.6532293558120728, 1.6532225608825684, 1.6531484127044678, 1.6531282663345337, 1.6530815362930298, 1.6531139612197876, 1.6531472206115723, 1.6531190872192383, 1.6531609296798706, 1.6530742645263672, 1.653058409690857, 1.6531858444213867, 1.6530959606170654]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.6284089088439941, 1.6428658962249756, 1.6547702550888062, 1.663315773010254, 1.6658481359481812, 1.6711702346801758, 1.6732029914855957, 1.6761558055877686, 1.6767487525939941, 1.6767340898513794, 1.674767017364502, 1.6754367351531982, 1.6735138893127441, 1.6756505966186523, 1.675991415977478, 1.6754581928253174, 1.67548668384552, 1.6765345335006714, 1.6768999099731445, 1.677769660949707]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# It seems that the model is learning a little on the training set but its predictions do not generalize at all on the validation set, the model is failing.

# %% [markdown]
# ### GRU

# %%
tf.keras.utils.get_file("/content/model_gru.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_gru.h5")
tf.keras.utils.get_file("/content/GRU_history.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/GRU_history.json")
GRU_history = json.load(open("/content/GRU_history.json", 'r'))
model_gru = tf.keras.models.load_model("/content/model_gru.h5")

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=GRU_history["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=GRU_history["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="62ecbae0-d226-4cd0-832b-7ed9faf65707" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("62ecbae0-d226-4cd0-832b-7ed9faf65707")) {
#                     Plotly.newPlot(
#                         '62ecbae0-d226-4cd0-832b-7ed9faf65707',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [1.659289002418518, 1.654719591140747, 1.6540935039520264, 1.6540709733963013, 1.653824806213379, 1.653497576713562, 1.6534172296524048, 1.654091715812683, 1.6535675525665283, 1.653470516204834, 1.6534721851348877, 1.6535980701446533, 1.6536674499511719, 1.6532739400863647, 1.6534805297851562, 1.6534230709075928, 1.6534020900726318, 1.6531535387039185, 1.653152585029602, 1.6530704498291016]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.653647780418396, 1.6760945320129395, 1.6650363206863403, 1.6748162508010864, 1.6809983253479004, 1.6814985275268555, 1.6903523206710815, 1.6785424947738647, 1.6646102666854858, 1.6899958848953247, 1.6766655445098877, 1.6801365613937378, 1.673147439956665, 1.667271614074707, 1.6812396049499512, 1.6743391752243042, 1.6822704076766968, 1.6789066791534424, 1.6694700717926025, 1.6738022565841675]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The exact same conclusion can be drawn for the GRU model, theonly difference being that each epoch is 5 times quicker to compute.

# %% [markdown]
# ### LSTM

# %%
tf.keras.utils.get_file("/content/model_lstm.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_lstm.h5")
tf.keras.utils.get_file("/content/LSTM_history.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/LSTM_history.json")
LSTM_history = json.load(open("/content/LSTM_history.json", 'r'))
model_lstm = tf.keras.models.load_model("/content/model_lstm.h5")

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=LSTM_history["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=LSTM_history["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="11acbac6-72ad-49f2-8c45-69511c5d7fea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11acbac6-72ad-49f2-8c45-69511c5d7fea")) {
#                     Plotly.newPlot(
#                         '11acbac6-72ad-49f2-8c45-69511c5d7fea',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [1.6593267917633057, 1.6550884246826172, 1.654089093208313, 1.6535876989364624, 1.654159426689148, 1.653718113899231, 1.6534346342086792, 1.6531487703323364, 1.6522700786590576, 1.6528546810150146, 1.6519975662231445, 1.6515600681304932, 1.6514869928359985, 1.651641845703125, 1.6515252590179443, 1.651402473449707, 1.6515291929244995, 1.6515432596206665, 1.6518003940582275, 1.6517220735549927]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.6371228694915771, 1.663527488708496, 1.6863588094711304, 1.6738306283950806, 1.675068736076355, 1.682855486869812, 1.677096962928772, 1.6759964227676392, 1.6824411153793335, 1.6676092147827148, 1.6779468059539795, 1.6735297441482544, 1.6854071617126465, 1.6776180267333984, 1.673372507095337, 1.6791311502456665, 1.673078179359436, 1.6779124736785889, 1.6778531074523926, 1.6786096096038818]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# We observe the exact same behaviour that we got from the GRU model.

# %% [markdown]
# ## Regression Modeling
#
# Since the classification modeling was not a great success, due mostly to the data being highly imbalanced, we'll attemps to treat this problem as a regression, which makes sense because the target variable is qualitative ordinale (this will affect the last layer and the choice of loss function and metric).

# %% [markdown]
# ### SimpleRNN

# %% [markdown]
# 1. Reproduce the same steps that we applied for the classification approach, except this time you will need to change the last layer in order to make predictions that fit a regression approach.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model_reg = tf.keras.Sequential([
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  SimpleRNN(units=64, return_sequences=True), # maintains the sequential nature
                  SimpleRNN(units=32, return_sequences=False), # returns the last output
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  Dense(1, activation="linear")
])

# %% [markdown]
# 2. When compiling the model you will have to choose loss and metric functions that are adapted to your regression approach.

# %%
optimizer= tf.keras.optimizers.Adam()

model_reg.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %% [markdown]
# 3. Fit the model for 20 epochs.

# %%
# Entrainement du modèle 
model_reg.fit(train_data,
              epochs=20, 
              validation_data=test_data)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 53s 548ms/step - loss: 2.4220 - mean_absolute_error: 1.2327 - val_loss: 1.7010 - val_mean_absolute_error: 1.0650
# Epoch 2/20
# 93/93 [==============================] - 51s 553ms/step - loss: 1.4183 - mean_absolute_error: 0.9572 - val_loss: 1.7072 - val_mean_absolute_error: 1.0747
# Epoch 3/20
# 93/93 [==============================] - 52s 562ms/step - loss: 1.4196 - mean_absolute_error: 0.9577 - val_loss: 1.6957 - val_mean_absolute_error: 1.0539
# Epoch 4/20
# 93/93 [==============================] - 50s 534ms/step - loss: 1.4188 - mean_absolute_error: 0.9579 - val_loss: 1.7634 - val_mean_absolute_error: 1.1317
# Epoch 5/20
# 93/93 [==============================] - 53s 566ms/step - loss: 1.4202 - mean_absolute_error: 0.9581 - val_loss: 1.7249 - val_mean_absolute_error: 1.0948
# Epoch 6/20
# 93/93 [==============================] - 52s 554ms/step - loss: 1.4223 - mean_absolute_error: 0.9580 - val_loss: 1.6875 - val_mean_absolute_error: 1.0358
# Epoch 7/20
# 93/93 [==============================] - 53s 567ms/step - loss: 1.4198 - mean_absolute_error: 0.9589 - val_loss: 1.7026 - val_mean_absolute_error: 1.0793
# Epoch 8/20
# 93/93 [==============================] - 51s 554ms/step - loss: 1.4231 - mean_absolute_error: 0.9587 - val_loss: 1.7200 - val_mean_absolute_error: 1.0965
# Epoch 9/20
# 93/93 [==============================] - 52s 555ms/step - loss: 1.3891 - mean_absolute_error: 0.9494 - val_loss: 1.6575 - val_mean_absolute_error: 1.0497
# Epoch 10/20
# 93/93 [==============================] - 52s 555ms/step - loss: 1.3641 - mean_absolute_error: 0.9397 - val_loss: 1.6341 - val_mean_absolute_error: 1.0231
# Epoch 11/20
# 93/93 [==============================] - 52s 558ms/step - loss: 1.3799 - mean_absolute_error: 0.9431 - val_loss: 1.7458 - val_mean_absolute_error: 1.1180
# Epoch 12/20
# 93/93 [==============================] - 52s 562ms/step - loss: 1.4011 - mean_absolute_error: 0.9537 - val_loss: 1.7314 - val_mean_absolute_error: 1.1105
# Epoch 13/20
# 93/93 [==============================] - 53s 566ms/step - loss: 1.3976 - mean_absolute_error: 0.9534 - val_loss: 1.6890 - val_mean_absolute_error: 1.0733
# Epoch 14/20
# 93/93 [==============================] - 52s 554ms/step - loss: 1.3922 - mean_absolute_error: 0.9513 - val_loss: 1.6631 - val_mean_absolute_error: 1.0574
# Epoch 15/20
# 93/93 [==============================] - 52s 559ms/step - loss: 1.3828 - mean_absolute_error: 0.9483 - val_loss: 1.6711 - val_mean_absolute_error: 1.0855
# Epoch 16/20
# 93/93 [==============================] - 51s 547ms/step - loss: 1.3822 - mean_absolute_error: 0.9484 - val_loss: 1.6890 - val_mean_absolute_error: 1.0631
# Epoch 17/20
# 93/93 [==============================] - 52s 557ms/step - loss: 1.3899 - mean_absolute_error: 0.9493 - val_loss: 1.6315 - val_mean_absolute_error: 1.0304
# Epoch 18/20
# 93/93 [==============================] - 52s 558ms/step - loss: 1.4055 - mean_absolute_error: 0.9535 - val_loss: 1.7397 - val_mean_absolute_error: 1.1078
# Epoch 19/20
# 93/93 [==============================] - 51s 552ms/step - loss: 1.4203 - mean_absolute_error: 0.9568 - val_loss: 1.7762 - val_mean_absolute_error: 1.1456
# Epoch 20/20
# 93/93 [==============================] - 51s 553ms/step - loss: 1.4230 - mean_absolute_error: 0.9607 - val_loss: 1.7547 - val_mean_absolute_error: 1.1222

# %% [markdown]
# 4. Save the model and the history dictionary and upload the files to your S3.

# %%
model_reg.save("model_simpleRNN_reg.h5")

# %%
import json
json.dump(model_reg.history.history, open("/content/simpleRNN_history_reg.json", 'w'))

# %% [markdown]
# ### GRU
#
# 1. Apply the same step, but replace the `SimpleRNN` layers by GRU layers.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model_gru_reg = tf.keras.Sequential([
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  GRU(units=64, return_sequences=True), # maintains the sequential nature
                  GRU(units=32, return_sequences=False), # returns the last output
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  Dense(1, activation="linear")
])

# %%
optimizer= tf.keras.optimizers.Adam()

model_gru_reg.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
model_gru_reg.fit(train_data,
              epochs=20, 
              validation_data=test_data)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 12s 90ms/step - loss: 2.7657 - mean_absolute_error: 1.2871 - val_loss: 1.6950 - val_mean_absolute_error: 1.0527
# Epoch 2/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.4146 - mean_absolute_error: 0.9555 - val_loss: 1.7361 - val_mean_absolute_error: 1.1051
# Epoch 3/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.4146 - mean_absolute_error: 0.9564 - val_loss: 1.7131 - val_mean_absolute_error: 1.0828
# Epoch 4/20
# 93/93 [==============================] - 8s 81ms/step - loss: 1.4178 - mean_absolute_error: 0.9572 - val_loss: 1.7419 - val_mean_absolute_error: 1.1099
# Epoch 5/20
# 93/93 [==============================] - 8s 82ms/step - loss: 1.3449 - mean_absolute_error: 0.9331 - val_loss: 1.2107 - val_mean_absolute_error: 0.8791
# Epoch 6/20
# 93/93 [==============================] - 8s 83ms/step - loss: 0.7695 - mean_absolute_error: 0.6474 - val_loss: 0.8363 - val_mean_absolute_error: 0.6717
# Epoch 7/20
# 93/93 [==============================] - 8s 83ms/step - loss: 0.5897 - mean_absolute_error: 0.5640 - val_loss: 0.8131 - val_mean_absolute_error: 0.6700
# Epoch 8/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.5204 - mean_absolute_error: 0.5288 - val_loss: 0.8033 - val_mean_absolute_error: 0.6303
# Epoch 9/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.4776 - mean_absolute_error: 0.5065 - val_loss: 0.8593 - val_mean_absolute_error: 0.5514
# Epoch 10/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.4442 - mean_absolute_error: 0.4813 - val_loss: 0.8161 - val_mean_absolute_error: 0.6252
# Epoch 11/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.4232 - mean_absolute_error: 0.4728 - val_loss: 0.8438 - val_mean_absolute_error: 0.5985
# Epoch 12/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.3966 - mean_absolute_error: 0.4580 - val_loss: 0.8668 - val_mean_absolute_error: 0.6212
# Epoch 13/20
# 93/93 [==============================] - 8s 81ms/step - loss: 0.3846 - mean_absolute_error: 0.4475 - val_loss: 0.8509 - val_mean_absolute_error: 0.6086
# Epoch 14/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.3583 - mean_absolute_error: 0.4339 - val_loss: 0.8778 - val_mean_absolute_error: 0.6162
# Epoch 15/20
# 93/93 [==============================] - 8s 83ms/step - loss: 0.3555 - mean_absolute_error: 0.4315 - val_loss: 0.8769 - val_mean_absolute_error: 0.6420
# Epoch 16/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.3412 - mean_absolute_error: 0.4215 - val_loss: 0.9059 - val_mean_absolute_error: 0.6147
# Epoch 17/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.3184 - mean_absolute_error: 0.4054 - val_loss: 0.9256 - val_mean_absolute_error: 0.5455
# Epoch 18/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.3005 - mean_absolute_error: 0.3889 - val_loss: 0.9193 - val_mean_absolute_error: 0.6021
# Epoch 19/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.2843 - mean_absolute_error: 0.3827 - val_loss: 0.9666 - val_mean_absolute_error: 0.5757
# Epoch 20/20
# 93/93 [==============================] - 8s 82ms/step - loss: 0.2694 - mean_absolute_error: 0.3685 - val_loss: 0.9745 - val_mean_absolute_error: 0.6190

# %%
model_gru_reg.save("model_gru_reg.h5")

# %%
import json
json.dump(model_gru_reg.history.history, open("/content/GRU_history_reg.json", 'w'))

# %% [markdown]
# ### LSTM
#
# 1. Reproduce the same steps, and use `LSTM` layers instead of `GRU` layers.

# %%
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, GRU, LSTM

vocab_size = 1000
model_lstm_reg = tf.keras.Sequential([
                  Embedding(vocab_size+1, 64, input_shape=[review.shape[1],],name="embedding"),
                  LSTM(units=64, return_sequences=True), # maintains the sequential nature
                  LSTM(units=32, return_sequences=False), # returns the last output
                  Dense(16, activation='relu'),
                  Dense(8, activation='relu'),

                  Dense(1, activation="linear", name="last")
])

# %%
optimizer= tf.keras.optimizers.Adam()

model_lstm_reg.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
model_lstm_reg.fit(train_data,
              epochs=20, 
              validation_data=test_data)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 12s 93ms/step - loss: 2.8046 - mean_absolute_error: 1.2989 - val_loss: 1.7380 - val_mean_absolute_error: 1.1063
# Epoch 2/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4161 - mean_absolute_error: 0.9563 - val_loss: 1.7353 - val_mean_absolute_error: 1.1041
# Epoch 3/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4171 - mean_absolute_error: 0.9582 - val_loss: 1.7118 - val_mean_absolute_error: 1.0806
# Epoch 4/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4230 - mean_absolute_error: 0.9582 - val_loss: 1.7068 - val_mean_absolute_error: 1.0740
# Epoch 5/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4193 - mean_absolute_error: 0.9599 - val_loss: 1.7126 - val_mean_absolute_error: 1.0816
# Epoch 6/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4179 - mean_absolute_error: 0.9580 - val_loss: 1.6987 - val_mean_absolute_error: 1.0607
# Epoch 7/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4202 - mean_absolute_error: 0.9587 - val_loss: 1.7032 - val_mean_absolute_error: 1.0687
# Epoch 8/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4198 - mean_absolute_error: 0.9565 - val_loss: 1.7062 - val_mean_absolute_error: 1.0732
# Epoch 9/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4184 - mean_absolute_error: 0.9560 - val_loss: 1.7249 - val_mean_absolute_error: 1.0947
# Epoch 10/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4226 - mean_absolute_error: 0.9622 - val_loss: 1.6946 - val_mean_absolute_error: 1.0087
# Epoch 11/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4247 - mean_absolute_error: 0.9583 - val_loss: 1.7995 - val_mean_absolute_error: 1.1668
# Epoch 12/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4227 - mean_absolute_error: 0.9591 - val_loss: 1.7104 - val_mean_absolute_error: 1.0789
# Epoch 13/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4159 - mean_absolute_error: 0.9568 - val_loss: 1.7537 - val_mean_absolute_error: 1.1208
# Epoch 14/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4215 - mean_absolute_error: 0.9603 - val_loss: 1.6911 - val_mean_absolute_error: 1.0263
# Epoch 15/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4271 - mean_absolute_error: 0.9633 - val_loss: 1.6880 - val_mean_absolute_error: 1.0392
# Epoch 16/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4213 - mean_absolute_error: 0.9573 - val_loss: 1.7465 - val_mean_absolute_error: 1.1130
# Epoch 17/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4187 - mean_absolute_error: 0.9576 - val_loss: 1.7201 - val_mean_absolute_error: 1.0900
# Epoch 18/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4168 - mean_absolute_error: 0.9568 - val_loss: 1.7318 - val_mean_absolute_error: 1.1012
# Epoch 19/20
# 93/93 [==============================] - 8s 84ms/step - loss: 1.4155 - mean_absolute_error: 0.9563 - val_loss: 1.7222 - val_mean_absolute_error: 1.0924
# Epoch 20/20
# 93/93 [==============================] - 8s 83ms/step - loss: 1.4183 - mean_absolute_error: 0.9574 - val_loss: 1.7155 - val_mean_absolute_error: 1.0853

# %%
model_lstm_reg.save("model_lstm_reg.h5")

# %%
import json
json.dump(model_lstm_reg.history.history, open("/content/LSTM_history_reg.json", 'w'))

# %% [markdown]
# ## Regression Evaluation
#
# Now it's time to visualize the results we obtained from the training jobs!

# %% [markdown]
# ### SimpleRNN
#
# 1. Visualize the results from the `SimpleRNN` model, what can you conclude?

# %%
import json

tf.keras.utils.get_file("/content/model_simpleRNN_reg.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_simpleRNN_reg.h5")
tf.keras.utils.get_file("/content/simpleRNN_history_reg.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/simpleRNN_history_reg.json")
simpleRNN_history_reg = json.load(open("/content/simpleRNN_history_reg.json", 'r'))
model_reg = tf.keras.models.load_model("/content/model_simpleRNN_reg.h5")

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=simpleRNN_history_reg["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=simpleRNN_history_reg["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1746585c-7e22-4dab-aa8d-e299ee7b1ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1746585c-7e22-4dab-aa8d-e299ee7b1ab5")) {
#                     Plotly.newPlot(
#                         '1746585c-7e22-4dab-aa8d-e299ee7b1ab5',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [2.4220328330993652, 1.4183086156845093, 1.4195823669433594, 1.418769121170044, 1.420173168182373, 1.422315239906311, 1.4198055267333984, 1.423129677772522, 1.389137625694275, 1.3640689849853516, 1.37986421585083, 1.4011088609695435, 1.3976492881774902, 1.3922311067581177, 1.3828035593032837, 1.382157802581787, 1.389899730682373, 1.4055407047271729, 1.4203362464904785, 1.4229930639266968]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.7009984254837036, 1.7072346210479736, 1.6957072019577026, 1.7634055614471436, 1.724908471107483, 1.6875019073486328, 1.7026374340057373, 1.7200287580490112, 1.6574552059173584, 1.634122371673584, 1.7458219528198242, 1.7314403057098389, 1.6889938116073608, 1.6630882024765015, 1.6710885763168335, 1.689043402671814, 1.6315234899520874, 1.739715576171875, 1.7762471437454224, 1.75472092628479]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The simpleRNN model seem to be learning something on the training data over the course of the first epoch, but then immediatly gets stuck. This may be due to either a vanishing gradient problem (which are quite common when using SimpleRNN layers).

# %% [markdown]
# ### GRU
# 1. Visualize the training results for the GRU model, what can you conclude?

# %%
tf.keras.utils.get_file("/content/model_gru_reg.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_gru_reg.h5")
tf.keras.utils.get_file("/content/GRU_history_reg.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/GRU_history_reg.json")
GRU_history_reg = json.load(open("/content/GRU_history_reg.json", 'r'))
model_gru_reg = tf.keras.models.load_model("/content/model_gru_reg.h5")
# Out:
# Downloading data from https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_gru_reg.h5
# 8380416/8374656 [==============================] - 1s 0us/step
# 8388608/8374656 [==============================] - 1s 0us/step
# Downloading data from https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/GRU_history_reg.json
# 16384/1684 [===================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=GRU_history_reg["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=GRU_history_reg["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="225a1207-d7dd-4d8d-962a-8dc4652da76c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("225a1207-d7dd-4d8d-962a-8dc4652da76c")) {
#                     Plotly.newPlot(
#                         '225a1207-d7dd-4d8d-962a-8dc4652da76c',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [2.7657394409179688, 1.4145913124084473, 1.4145722389221191, 1.4178471565246582, 1.3448973894119263, 0.7695252299308777, 0.589665412902832, 0.5203701257705688, 0.47755804657936096, 0.4442136585712433, 0.42317524552345276, 0.39662137627601624, 0.38458821177482605, 0.3583361804485321, 0.35545194149017334, 0.3412451148033142, 0.31839480996131897, 0.3005205988883972, 0.28432703018188477, 0.26938238739967346]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.6950191259384155, 1.7361338138580322, 1.7130545377731323, 1.7418848276138306, 1.2106609344482422, 0.8363063335418701, 0.8131428956985474, 0.8032669425010681, 0.8592615127563477, 0.8160609006881714, 0.8438451290130615, 0.8668105602264404, 0.8508802652359009, 0.8778029084205627, 0.8768974542617798, 0.9059025049209595, 0.9255545735359192, 0.9192600846290588, 0.9666137099266052, 0.9745206236839294]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The results from the GRU model are actually quite good! The model continuously learns form the training examples, and starts overfitting after epoch number 7. This is a schoolbook example of model training right here!
#
# In addition to this, the MSE on the validation data is around 0.8, which means that on average the prediction error is below 1 point, which is encouraging!

# %% [markdown]
# ### LSTM
#
# 1. Now it's time to visualize the results for the LSTM model.

# %%
tf.keras.utils.get_file("/content/model_lstm_reg.h5",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_lstm_reg.h5")
tf.keras.utils.get_file("/content/LSTM_history_reg.json",
                        origin="https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/LSTM_history_reg.json")
LSTM_history_reg = json.load(open("/content/LSTM_history_reg.json", 'r'))
model_lstm_reg = tf.keras.models.load_model("/content/model_lstm_reg.h5")
# Out:
# Downloading data from https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/model_lstm_reg.h5
# 8511488/8507416 [==============================] - 1s 0us/step
# 8519680/8507416 [==============================] - 1s 0us/step
# Downloading data from https://full-stack-assets.s3.eu-west-3.amazonaws.com/models/M08_Deep_learning/Text_classification/LSTM_history_reg.json
# 16384/1667 [======================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=LSTM_history_reg["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=LSTM_history_reg["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb48788a-819b-408f-8da5-02946f431eb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb48788a-819b-408f-8da5-02946f431eb5")) {
#                     Plotly.newPlot(
#                         'bb48788a-819b-408f-8da5-02946f431eb5',
#                         [{"mode": "lines", "name": "loss", "type": "scatter", "y": [3.3736517429351807, 1.4146960973739624, 1.413751244544983, 1.4147913455963135, 1.4151042699813843, 1.4140897989273071, 1.4142142534255981, 1.4145904779434204, 1.4160728454589844, 1.4188551902770996, 1.4150378704071045, 1.4168838262557983, 1.4168357849121094, 1.4183679819107056, 1.417013168334961, 1.414273738861084, 1.4167284965515137, 1.415970802307129, 1.4147958755493164, 1.4149205684661865]}, {"mode": "lines", "name": "val_loss", "type": "scatter", "y": [1.7326934337615967, 1.7089613676071167, 1.7254852056503296, 1.7139582633972168, 1.7172797918319702, 1.7119431495666504, 1.744362711906433, 1.7453609704971313, 1.7105509042739868, 1.6999253034591675, 1.69678795337677, 1.7094099521636963, 1.7335811853408813, 1.7045830488204956, 1.7045745849609375, 1.6973563432693481, 1.7519326210021973, 1.7127354145050049, 1.719388484954834, 1.7036986351013184]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The results for the LSTM model are disappointing, the model gets immediatly stuck. Although performances of GRU and LSTM layers are mostof the time comparable, in this specific caseit seems that GRU layers handle the gradients better and have an easier time training.
