# %% [markdown]
# # Kayak

# %% [markdown]
# * Voir : https://app.jedha.co/course/project-plan-your-trip-with-kayak-ft/plan-your-trip-with-kayak-ft

# %%
# ouvre le fichier hotels_list.json
# construit lune liste start_urls
# start_urls = [
#       #"https://www.booking.com/hotel/fr/ha-tel-marseille-vieux-port.fr.html",
#       #"https://www.booking.com/hotel/fr/hotelkyriadrabatau.fr.html",
#       "https://www.booking.com/hotel/fr/citea-marseille-prado-perier.fr.html",
#     ]
# on veut 

import json

# Ouvrir le fichier JSON et le lire
with open('hotels_list.json', 'r') as f:
    data = json.load(f)

# Initialiser une liste pour stocker les URLs
list_urls = []

# Parcourir les données et extraire les URLs
for entry in data:
    list_urls.append(entry['url'])

# Afficher la liste des URLs
print(list_urls)
# Out:
# ['https://www.booking.com/hotel/fr/suite-en-plein-coeur-du-panier-47-vieux-port.fr.html', 'https://www.booking.com/hotel/fr/residence-kley.fr.html', 'https://www.booking.com/hotel/fr/staycity-aparthotels-centre-vieux-port.fr.html', 'https://www.booking.com/hotel/fr/odalys-city-marseille-centre-euromed.fr.html', 'https://www.booking.com/hotel/fr/le-panier-enchante-suites-amp-spa.fr.html', 'https://www.booking.com/hotel/fr/hipark-residences-marseille.fr.html', 'https://www.booking.com/hotel/fr/sweet-design-suite-vieux-port.fr.html', 'https://www.booking.com/hotel/fr/seven-urban-suites.fr.html', 'https://www.booking.com/hotel/fr/hotelkyriadrabatau.fr.html', 'https://www.booking.com/hotel/fr/crowne-plaza-marseille-le-dome.fr.html', 'https://www.booking.com/hotel/fr/lafrenchcasa-canebiere.fr.html', 'https://www.booking.com/hotel/fr/nhow-marseille.fr.html', 'https://www.booking.com/hotel/fr/citadines-aparthotel-marseillepradochanot.fr.html', 'https://www.booking.com/hotel/fr/la-french-casa
# ...

# %%
from datetime import datetime, timedelta

aujourdhui = datetime.today()
date_future = aujourdhui + timedelta(days=15)
date_future_str = date_future.strftime('%Y-%m-%d')

# Afficher la date future
print(aujourdhui.strftime('%Y-%m-%d'))
print(date_future_str)
# Out:
# 2024-04-07
# 2024-04-22

# %%
# prelude
import pandas as pd
import requests

import my_api_id as key
openweathermap_key = key.openweathermap

# %%
ma_liste = [
  "Mont Saint Michel",
  "St Malo",
  "Bayeux",
  "Le Havre",
  "Rouen",
]

# ma_liste = [
#   "Mont Saint Michel",
#   "St Malo",
#   "Bayeux",
#   "Le Havre",
#   "Rouen",
#   "Paris",
#   "Amiens",
#   "Lille",
#   "Strasbourg",
#   "Chateau du Haut Koenigsbourg",
#   "Colmar",
#   "Eguisheim",
#   "Besancon",
#   "Dijon",
#   "Annecy",
#   "Grenoble",
#   "Lyon",
#   "Gorges du Verdon",
#   "Bormes les Mimosas",
#   "Cassis",
#   "Marseille",
#   "Aix en Provence",
#   "Avignon",
#   "Uzes",
#   "Nimes",
#   "Aigues Mortes",
#   "Saintes Maries de la mer",
#   "Collioure",
#   "Carcassonne",
#   "Ariege",
#   "Toulouse",
#   "Montauban",
#   "Biarritz",
#   "Bayonne",
#   "La Rochelle"
# ]

# %%
# Testing
url = "https://nominatim.openstreetmap.org/search"

params = {
  "q"       : "Bayonne",
  "format"  : "json",
}

response = requests.get(url, params=params) 
response.json()

# print(response.json()[0]["lat"])
# print(response.json()[0]["lon"])
# Out:
# [{'place_id': 252689850,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 166713,
#   'lat': '43.4945144',
#   'lon': '-1.4736657',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 16,
#   'importance': 0.6027800210035323,
#   'addresstype': 'town',
#   'name': 'Bayonne',
#   'display_name': 'Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64100, France',
#   'boundingbox': ['43.4498733', '43.5188846', '-1.5048438', '-1.4172610']},
#  {'place_id': 311414097,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 170504,
#   'lat': '40.6687141',
#   'lon': '-74.1143091',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 16,
#   'importance': 0.4914895930584272,
#   'addresstype': 'city',
#   'name': 'Bayonne',
# ...

# %%
# Testing
for ville in ma_liste:
  print(ville)
# url = "https://nominatim.openstreetmap.org/search"

# params = {
#   "q"       : "Bayonne",
#   "format"  : "json",
# }

# response = requests.get(url, params=params) 

# print(response.json()[0]["lat"])
# print(response.json()[0]["lon"])
# Out:
# Mont Saint Michel
# St Malo
# Bayeux
# Le Havre
# Rouen

# %%
df = pd.DataFrame(columns=["site", "latitude", "longitude"])
df
# Out:
# Empty DataFrame
# Columns: [site, latitude, longitude]
# Index: []

# %%
url = "https://nominatim.openstreetmap.org/search"

for site in ma_liste:
  params = {
    "q" : site,
    "format":"json",
  }
  response = requests.get(url, params=params) 
  list_tmp = [site, response.json()[0]["lat"], response.json()[0]["lon"]]
  df.loc[len(df)] = list_tmp

df
# Out:
#                 site    latitude           longitude
# 0  Mont Saint Michel  48.6359541  -1.511459954959514
# 1            St Malo   49.314695         -96.9538228
# 2             Bayeux  49.2764624          -0.7024738
# 3           Le Havre  49.4938975           0.1079732
# 4              Rouen  49.4404591           1.0939658

# %%
# Testing


url = "http://api.openweathermap.org/data/2.5/forecast"

params = {
  "q" : "Bayonne,fr",
  "appid" : openweathermap_key
}

response = requests.get(url, params=params) 
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1711692000,
#    'main': {'temp': 287.09,
#     'feels_like': 286.42,
#     'temp_min': 284.81,
#     'temp_max': 287.09,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 968,
#     'humidity': 72,
#     'temp_kf': 2.28},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2, 'deg': 290, 'gust': 3.73},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 06:00:00'},
#   {'dt': 1711702800,
#    'main': {'temp': 286.03,
#     'feels_like': 285.44,
#     'temp_min': 283.9,
#     'temp_max': 286.03,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 970,
#     'humidity': 79,
#     'temp_kf': 2.13},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
# ...

# %%
# Testing

url = "http://api.openweathermap.org/data/2.5/forecast"

# Bayonne
params = {
  "lat" : "43.3333",
  "lon" : "-1.4167",
  "appid" : openweathermap_key,
}

response = requests.get(url, params=params) 
response.json()

# print(response.json()[0]["lat"])
# print(response.json()[0]["lon"])
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1711692000,
#    'main': {'temp': 287.09,
#     'feels_like': 286.42,
#     'temp_min': 284.81,
#     'temp_max': 287.09,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 968,
#     'humidity': 72,
#     'temp_kf': 2.28},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2, 'deg': 290, 'gust': 3.73},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-29 06:00:00'},
#   {'dt': 1711702800,
#    'main': {'temp': 286.03,
#     'feels_like': 285.44,
#     'temp_min': 283.9,
#     'temp_max': 286.03,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 970,
#     'humidity': 79,
#     'temp_kf': 2.13},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
# ...

# %%
# https://medium.com/towards-data-science/all-pandas-json-normalize-you-should-know-for-flattening-json-13eae1dfb7dd
df_tmp = pd.json_normalize(response.json(), max_level=1)
display(df_tmp)
# Out:
#    cod  message  cnt                                               list  \
# 0  200        0   40  [{'dt': 1711692000, 'main': {'temp': 287.09, '...
#
#    city.id                  city.name                        city.coord  \
# 0  3034473  Arrondissement de Bayonne  {'lat': 43.3333, 'lon': -1.4167}
#
#   city.country  city.population  city.timezone  city.sunrise  city.sunset
# 0           FR           268739           3600    1711691531   1711736892

# %%
df_tmp = pd.json_normalize(response.json(), max_level=2)
display(df_tmp)
# Out:
#    cod  message  cnt                                               list  \
# 0  200        0   40  [{'dt': 1711692000, 'main': {'temp': 287.09, '...
#
#    city.id                  city.name  city.coord.lat  city.coord.lon  \
# 0  3034473  Arrondissement de Bayonne         43.3333         -1.4167
#
#   city.country  city.population  city.timezone  city.sunrise  city.sunset
# 0           FR           268739           3600    1711691531   1711736892

# %%
df_tmp = pd.json_normalize(response.json()["list"], record_path=["weather"])
# df_tmp = df_tmp.transpose()
display(df_tmp)
# Out:
#      id    main           description icon
# 0   500    Rain            light rain  10d
# 1   500    Rain            light rain  10d
# 2   500    Rain            light rain  10d
# 3   501    Rain         moderate rain  10d
# 4   502    Rain  heavy intensity rain  10d
# 5   502    Rain  heavy intensity rain  10n
# 6   500    Rain            light rain  10n
# 7   500    Rain            light rain  10n
# 8   803  Clouds         broken clouds  04d
# 9   803  Clouds         broken clouds  04d
# 10  804  Clouds       overcast clouds  04d
# 11  803  Clouds         broken clouds  04d
# 12  803  Clouds         broken clouds  04d
# 13  804  Clouds       overcast clouds  04n
# 14  804  Clouds       overcast clouds  04n
# 15  804  Clouds       overcast clouds  04n
# 16  804  Clouds       overcast clouds  04d
# 17  500    Rain            light rain  10d
# 18  500    Rain            light rain  10d
# 19  500    Rain            light rain  10d
# 20  500    Rain            light rain  10d
# ...

# %%
df_tmp = pd.json_normalize(response.json(), record_path=["list"])
display(df_tmp)
# Out:
#             dt                                            weather  visibility  \
# 0   1711692000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1   1711702800  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2   1711713600  [{'id': 500, 'main': 'Rain', 'description': 'l...        3044
# 3   1711724400  [{'id': 501, 'main': 'Rain', 'description': 'm...        1000
# 4   1711735200  [{'id': 502, 'main': 'Rain', 'description': 'h...         670
# 5   1711746000  [{'id': 502, 'main': 'Rain', 'description': 'h...        4533
# 6   1711756800  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 7   1711767600  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 8   1711778400  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 9   1711789200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 10  1711800000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# ...

# %%
# df4 = pd.concat([df1, df2], axis=1)

# %%
my_timestamp = pd.to_datetime(response.json()["list"][t]["dt_txt"])
print(my_timestamp.strftime("%d/%m %H:%M"), round((response.json()["list"][t]["main"]["temp"]-273.0),2))
# Out:
# 02/04 18:00 13.39

# %%
# Testing

nb = len(response.json()["list"])
for t in range(nb):
  my_timestamp = pd.to_datetime(response.json()["list"][t]["dt_txt"])
  print(my_timestamp.strftime("%d/%m %H:%M"), round((response.json()["list"][t]["main"]["temp"]-273.0),2))
# Out:
# 28/03 21:00 18.06
# 29/03 00:00 17.54
# 29/03 03:00 15.3
# 29/03 06:00 10.19
# 29/03 09:00 12.86
# 29/03 12:00 14.19
# 29/03 15:00 12.25
# 29/03 18:00 10.21
# 29/03 21:00 8.4
# 30/03 00:00 6.79
# 30/03 03:00 6.02
# 30/03 06:00 5.72
# 30/03 09:00 12.49
# 30/03 12:00 15.17
# 30/03 15:00 16.32
# 30/03 18:00 11.92
# 30/03 21:00 9.6
# 31/03 00:00 10.49
# 31/03 03:00 9.57
# 31/03 06:00 9.81
# 31/03 09:00 10.51
# 31/03 12:00 13.51
# 31/03 15:00 14.57
# 31/03 18:00 12.09
# 31/03 21:00 10.65
# 01/04 00:00 10.17
# 01/04 03:00 10.31
# 01/04 06:00 10.21
# 01/04 09:00 13.81
# 01/04 12:00 15.74
# 01/04 15:00 13.2
# 01/04 18:00 10.6
# 01/04 21:00 9.35
# 02/04 00:00 7.33
# 02/04 03:00 6.54
# 02/04 06:00 6.28
# 02/04 09:00 14.19
# 02/04 12:00 16.56
# 02/04 15:00 16.85
# 02/04 18:00 13.39

# %%
df_weather = pd.DataFrame(columns=["Site", "latitude", "longitude", ""])
df_weather
# Out:
# Empty DataFrame
# Columns: [Site, latitude, longitude, ]
# Index: []

# %%
url = "http://api.openweathermap.org/data/2.5/forecast"


for index, row in df.iterrows():
  if (index==5):
    break
  latitude = row['latitude']
  longitude = row['longitude']
  site = row['site']

  # print(latitude, longitude)

  params = {
    "lat" : latitude,
    "lon" : longitude,
    "appid" : openweathermap_key,
  }
  
  response = requests.get(url, params=params) 
  # list_tmp = [site, response.json()[0]["lat"], response.json()[0]["lon"]]
  # df.loc[len(df)] = list_tmp
  my_timestamp = pd.to_datetime(response.json()["list"][0]["dt_txt"])
  print(site, my_timestamp.strftime("%d/%m %H:%M"), round((response.json()["list"][t]["main"]["temp"]-273.0),2))

# df
# Out:
# Mont Saint Michel 28/03 21:00 9.91
# St Malo 28/03 21:00 5.08
# Bayeux 28/03 21:00 10.31
# Le Havre 28/03 21:00 10.92
# Rouen 28/03 21:00 10.6

# %% [markdown]
# * Aller lire : https://openweathermap.org/forecast5
# * Comment faire un indice météo ?
# * pop = proba de pluie etc.
# * Faire un radar chart avec vent, proba pluie, soleil, temp... ?
# * Voir comment récupérer les icones qui sont dans response.json()["list"]
#   * https://openweathermap.org/weather-conditions
#   * https://stackoverflow.com/questions/44177417/how-to-display-openweathermap-weather-icon

# %% [markdown]
# <img src="https://openweathermap.org/img/wn/01d@2x.png"/>
# <img src="https://openweathermap.org/img/wn/02d@2x.png"/>
# <img src="https://openweathermap.org/img/wn/03d@2x.png"/>

# %% [markdown]
# https://www.booking.com/searchresults.fr.html?ss=Paris&checkin=2024-04-02&checkout=2024-04-05&group_adults=2&no_rooms=1&group_children=0

# %%
import re

# latitude Paris = 48.5
# str = 'dsfs sdfsdf  sdfsdf data-atlas-latlng="49.27603159,-0.70172489" sdfsdf sdfs sdfsdfsdf'
str = "<a id=\"hotel_sidebar_static_map\" class=\"loc_block_link_underline_fix \nmap_static_zoom show_map map_static_hover jq_tooltip map_static_button_hoverstate maps-more-static-focus txp-fix-hover \n\" href=\"#map_opened-hotel_sidebar_static_map\" data-atlas-latlng=\"49.27603159,-0.70172489\" data-lang-for-url=\"fr\" data-action=\"hotel\" data-api-key=\"AIzaSyDXrqUc7k84GZ0W6P5sMFrKFMVIdN-Nd0w\" data-atlas-bbox=\"49.2580661691929,-0.729312459909215,49.2939970023391,-0.674137313879237\" style=\" height:200px; background: url(https://maps.googleapis.com/maps/api/staticmap?zoom=13&amp;language=fr&amp;channel=hotel&amp;key=AIzaSyDXrqUc7k84GZ0W6P5sMFrKFMVIdN-Nd0w&amp;size=264x200&amp;center=49.27603159,-0.70172489&amp;signature=vw0aiEsLvjH3HpPtTeyAhzDmgck=) center; \" data-source=\"map_thumbnail\" data-map-open-text=\"Retour \u00e0 l'\u00e9tablissement\" role=\"button\">\n<div class=\"txp-map-cta-wrap\">\n<button class=\"txp-map-cta bui-button bui-button--primary\" data-map-open-text=\"Retour \u00e0 l'\u00e9tablissement\" data-map-thumb-label>\n<span class=\"bui-button__text\">\nVoir sur la carte\n</span>\n</button>\n</div>\n<span class=\"map-thumb__marker--current\">\n<svg class=\"property-marker\" xmlns=\"http://www.w3.org/2000/svg\" viewbox=\"0 0 18 29\">\n<ellipse class=\"shadow\" fill=\"#000000\" fill-opacity=\"0.24\" cx=\"9\" cy=\"27\" rx=\"6\" ry=\"2\"></ellipse>\n<path class=\"pin\" d=\"M9,27 C7,27 0,16.9704016 0,9 C2.28269391e-16,4.02943725 4.02943725,0 9,0 C13.9705627,0 18,4.02943725 18,9 C18,16.9704016 11,27 9,27 Z M9,13 C11.209139,13 13,11.209139 13,9 C13,6.790861 11.209139,5 9,5 C6.790861,5 5,6.790861 5,9 C5,11.209139 6.790861,13 9,13 Z\"></path>\n</svg>\n</span>\n</a>"
numbers = re.findall('[+-]*\d+\.\d+', str)
# latitude = re.findall("\d+\.\d+", "Current Level: 13.4db.")
latitude = numbers[0]
longitude = numbers[1]
print(latitude)
print(longitude)
# Out:
# 49.27603159
# -0.70172489
