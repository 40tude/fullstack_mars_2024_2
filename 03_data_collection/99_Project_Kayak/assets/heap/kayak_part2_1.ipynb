# %% [markdown]
# # Kayak

# %% [markdown]
# * Voir : https://app.jedha.co/course/project-plan-your-trip-with-kayak-ft/plan-your-trip-with-kayak-ft
#
# Summary
# * 70% of the users who are planning a trip would like to have more information about the destination they are going to.
# * People tend to be defiant about the information they are reading if they don't know the brand which produced the content => SOURCING
# * Therefore, Kayak Marketing Team would like to create an application that will recommend where people should plan their next holidays.
# * The application should be based on real data about:
#     * Weather
#     * Hotels in the area
# * The application should then be able to recommend the best destinations and hotels based on the above variables at any given time.

# %% [markdown]
# ## Helpers
#
# <!-- ### Get weather data with an API
#
# 1. DONE - Use https://nominatim.org/ to get the gps coordinates of all the cities (no subscription required) Documentation : https://nominatim.org/release-docs/develop/api/Search/
#
# 1. DONE - Use https://openweathermap.org/appid and https://openweathermap.org/api/one-call-api to get some information about the weather for the 35 cities and put it in a DataFrame
#
# 1. DONE - Determine the list of cities where the weather will be the nicest within the next 7 days For example, you can use the values of daily.pop and daily.rain to compute the expected volume of rain within the next 7 days... But it's only an example, actually you can have different opinions on a what a nice weather would be like 😎 Maybe the most important criterion for you is the temperature or humidity, so feel free to change the rules !
#
#
# 1. DONE - Save all the results in a `.csv` file, you will use it later. You can save all the informations that seem important to you ! Don't forget to save the name of the cities, and also to create a column containing a unique identifier (id) of each city (this is important for what's next in the project)
#
# 1. DONE - Use plotly to display the best destinations on a map -->
#
#
#
#
#
#
# ### Scrape Booking.com
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information as you want, but we suggest that you get at least:
#
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel
#
# TOP 20 hotels
#
#
#
#
# <!--
# ### Create your data lake using S3
#
# Once you managed to build your dataset, you should store into S3 as a csv file.
#
# ### ETL
#
# Once you uploaded your data onto S3, it will be better for the next data analysis team to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, extract your data from S3 and store it in your newly created DB.
#  -->

# %%
# prelude
import time
import json
import pandas as pd

from pathlib import Path

import my_api_id as key

kOpenWeatherMapKey  = key.openweathermap
kGold               = 1.618
kWidth              = 12
kHeight             = kWidth/kGold
kWidthPx            = 1024
kHeightPx           = kWidthPx/kGold

# kCurrentDir         = Path(__file__).parent
kFilename           = "cities.csv"
kOneCityFile        = "one_city.json"
kHotelsListFile     = "hotels_list.json"
kHotelsAttributes   = "hotels_attributes.json"

# %% [markdown]
# # 1. Get the top n cities

# %%
df_cities = pd.read_csv(kFilename, nrows = 3)
# df = pd.read_csv(kFilename)
df_cities.rename(columns={"Unnamed: 0": "id"}, inplace=True)
df_cities.head(10)
# Out:
#    id             city   latitude  longitude   temp  rain
# 0   0  Aix en Provence  43.529842   5.447474  17.80  0.00
# 1   1         Grenoble  45.187560   5.735782  17.68  0.00
# 2   2             Lyon  45.757814   4.832011  17.15  2.05

# %% [markdown]
# # 2. For each city generate a list of hotels

# %%
# Pour chaque ville de la table
#   Si il existe, supprimer le fichier one_city.json
#   Generer un fichier one_city.json avec le nom de la ville

#   Si il existe, supprimer le fichier hotels_lists.json
#   Invoquer sraper8_hotels_per_city
#   Attendre que le fichier hotels_lists.json soit généré

#   Si il existe, supprimer le fichier hotel_attributes.json
#   Invoquer scraper7_attributes
#   Attentendre que le fichier hotel_attributes.json soit généré

#

# %%
for index, row in df_cities.iterrows():

  pathToOneCityFile = Path(kOneCityFile)  
  if Path.exists(pathToOneCityFile):
    (pathToOneCityFile).unlink()

  current_ligne = row.to_list()
  entry = '[{"city" : '  +   f'"{current_ligne[1]}"'   +   "}]"
  with open(pathToOneCityFile, 'w') as f:
    f.write(entry)

# %%
pathToHotelsListFile = Path(kHotelsListFile)  
if Path.exists(pathToHotelsListFile):
  (pathToHotelsListFile).unlink()

# !python "scraper8_hotels_per_city.py"

print("DONE : Getting the names of the hotels for the currunt city")
print()
# Out:
# DONE : Getting the names of the hotels for the currunt city

# %%
# The file we are waiting for
expected_file = Path(kHotelsListFile)

while not expected_file.exists():
    time.sleep(1)  # Attendre une seconde avant de vérifier à nouveau

# Continuer l'exécution du notebook une fois que le fichier JSON est créé
print("The json file with the list of hotels of the current city is created")
print("Let's move forward")
# Out:
# The json file with the list of hotels names and URL is created
# Let's move forward

# %%
pathToHotelsAttributes = Path(kHotelsAttributes)  
if Path.exists(pathToHotelsAttributes):
  (pathToHotelsAttributes).unlink()

# !python "scraper7_attributes.py"

print("DONE : Getting the attributes of the hotels of the list of the currunt city")
print()
# Out:
# DONE : Getting the attributes of the hotels of the list of the currunt city

# %%
# The file we are waiting for
expected_file = Path(kHotelsAttributes)

while not expected_file.exists():
    time.sleep(1)  # Attendre une seconde avant de vérifier à nouveau

# Continuer l'exécution du notebook une fois que le fichier JSON est créé
print("The json file with the attributes of the hotels of the list of the current city")
print("Let's move forward")
# Out:
# The json file with the attributes of the hotels of the list of the current city
# Let's move forward

# %%
# At this point
# df_cities         contains the cities, latitude, long, temp and rain forecast
# one_city.json     contain the name of the town
# hotels_list.json  contains the names of the hotels of the town
# hotels_attributes.json contains, in order, the attributes of each hotels of the list

# let's store all these data in a DataFrame

df_attributes = pd.read_json("./hotels_attributes.json")
# df_attributes.head()

df_hotels = pd.read_json("./hotels_list.json")
# df_hotels.head() 

df = pd.concat([df_hotels, df_attributes], axis=1)
# df.head()

# 	id	city	latitude	longitude	temp	rain
current_index = 2
df["city"] = row = df_cities.iloc[current_index][1]
df["latitude_city"] = row = df_cities.iloc[current_index][2]
df["longitude_city"] = row = df_cities.iloc[current_index][3]
df["temp"] = row = df_cities.iloc[current_index][4]
df["rain"] = row = df_cities.iloc[current_index][5]
display(df)
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_19000\3970534337.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["city"] = row = df_cities.iloc[current_index][1]
# C:\Users\phili\AppData\Local\Temp\ipykernel_19000\3970534337.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["latitude_city"] = row = df_cities.iloc[current_index][2]
# C:\Users\phili\AppData\Local\Temp\ipykernel_19000\3970534337.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["longitude_city"] = row = df_cities.iloc[current_index][3]
# C:\Users\phili\AppData\Local\Temp\ipykernel_19000\3970534337.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["temp"] = row = df_cities.iloc[current_index][4]
# C:\Users\phili\AppData\Local\Temp\ipykernel_19000\3970534337.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["rain"] = row = df_cities.iloc[current_index][5]
#                                                 hotel  \
# 0                                 Les Cocons Heritage
# 1                           Citadines Presqu'île Lyon
# 2             Campanile Lyon Centre - Berges du Rhône
# 3                            Boscolo Lyon Hotel & Spa
# 4                   Best Western Hotel du Pont Wilson
# 5                                     Hôtel du Helder
# 6                             TRIBE Lyon Croix Rousse
# 7                   Hôtel Charlemagne by Happyculture
# 8   Hôtel Chromatics & Restaurant Hill Club by Hap...
# 9                                       Collège Hôtel
# 10                    Hotel des Savoies Lyon Perrache
# 11                                       La Résidence
# 12  Les Bulles de Mona "Le 93" -PROXIMITE GARE DE ...
# 13            Hotel Victoria Lyon Perrache Confluence
# 14                                           21Royale
# 15                               Résidence Villemanzy
# 16                        Greet Hotel Lyon Confluence
# 17              MEININGER Hotel Lyon Centre Berthelot
# 18     Hotel Carlton Lyon - MGallery Hotel Collection
# 19                                  MiHotel Gailleton
# 20                                  Hotelo Lyon Ainay
# 21  Les Bulles de Mona "Le 149" -PROXIMITE GARE DE...
# 22                        Hotel Des Remparts Perrache
# 23                                   Hotel du Théatre
# 24                                  MiHotel Bellecour
#
#                                                   url  score   latitude  \
# 0   https://www.booking.com/hotel/fr/les-cocons-he...    7.8  45.756962
# 1   https://www.booking.com/hotel/fr/citadines-apa...    8.4  45.761587
# 2   https://www.booking.com/hotel/fr/bleumarinelyo...    7.1  45.756700
# 3   https://www.booking.com/hotel/fr/boscolo-exedr...    8.4  45.760833
# 4   https://www.booking.com/hotel/fr/lyon-wilson.f...    8.3  45.758431
# 5   https://www.booking.com/hotel/fr/hotelduhelder...    6.4  45.752111
# 6   https://www.booking.com/hotel/fr/tribe-lyon-cr...    8.7  45.782350
# 7   https://www.booking.com/hotel/fr/hotelbestwest...    8.0  45.746023
# 8   https://www.booking.com/hotel/fr/perrache.fr.html    7.6  45.744684
# 9    https://www.booking.com/hotel/fr/college.fr.html    8.1  45.765711
# 10  https://www.booking.com/hotel/fr/hoteldessavoi...    7.6  45.749736
# 11  https://www.booking.com/hotel/fr/laresidenlyon...    7.9  45.755278
# 12  https://www.booking.com/hotel/fr/appartement-d...    8.1  45.758873
# 13  https://www.booking.com/hotel/fr/victoria-lyon...    7.7  45.748181
# 14  https://www.booking.com/hotel/fr/21royale-lyon...    7.5  45.770832
# 15  https://www.booking.com/hotel/fr/residence-vil...    7.5  45.771935
# 16  https://www.booking.com/hotel/fr/greet-hotel-l...    8.1  45.748458
# 17  https://www.booking.com/hotel/fr/meininger-lyo...    8.4  45.746083
# 18  https://www.booking.com/hotel/fr/carlton-lyon....    8.6  45.760988
# 19  https://www.booking.com/hotel/fr/mi-digital-ap...    8.2  45.755555
# 20  https://www.booking.com/hotel/fr/hoteldelaloir...    7.8  45.750422
# 21  https://www.booking.com/hotel/fr/les-bulles-de...    8.7  45.755362
# 22  https://www.booking.com/hotel/fr/hoteldesrempa...    7.9  45.750554
# 23  https://www.booking.com/hotel/fr/du-theatre-ly...    7.8  45.760215
# 24  https://www.booking.com/hotel/fr/mihotel-belle...    8.1  45.758703
#
#     longitude                                        description  city  \
# 0    4.872820  Situé à Lyon, à moins de 1,7 km de la gare de ...  Lyon
# 1    4.832627  Le Citadines Presqu'île Lyon est situé dans le...  Lyon
# 2    4.841953  Le Campanile Lyon Centre - Berges du Rhône pro...  Lyon
# 3    4.837589  Le Boscolo Lyon Hotel & Spa occupe un bâtiment...  Lyon
# 4    4.841479  Installé dans le centre-ville de Lyon, le Best...  Lyon
# 5    4.840485  Situé dans le centre de Lyon, l'Hôtel du Helde...  Lyon
# 6    4.833780  Situé à Lyon, à 1,9 km du musée des beaux-arts...  Lyon
# 7    4.823894  L’Hôtel Charlemagne by Happyculture se trouve ...  Lyon
# 8    4.825809  L’Hôtel Chromatics & Restaurant Hill Club by H...  Lyon
# 9    4.827827  Bénéficiant d’un emplacement central dans la v...  Lyon
# 10   4.829850  Situé dans le quartier de la Presqu&#39;île de...  Lyon
# 11   4.830482  Situé dans une rue piétonne de la presqu'île d...  Lyon
# 12   4.867913  Les Bulles de Mona "Le 93" -PROXIMITE Situé à ...  Lyon
# 13   4.828566  L'Hotel Victoria Lyon Perrache Confluence vous...  Lyon
# 14   4.837335  L'établissement 21Royale est situé dans un imm...  Lyon
# 15   4.835458  Offrant une vue sur les Alpes et le Rhône, la ...  Lyon
# 16   4.827753  Situé à Lyon, dans le quartier de la Presqu’îl...  Lyon
# 17   4.837187  Installé à Lyon, le MEININGER Hotel Lyon Centr...  Lyon
# 18   4.836726  Occupant un bâtiment datant de 1894, l’Hotel C...  Lyon
# 19   4.830104  Le MiHotel Gailleton vous accueille dans le ce...  Lyon
# 20   4.825989  L’Hotelo Lyon Ainay vous propose des hébergeme...  Lyon
# 21   4.867172  Doté d'une baignoire spa, l'établissement Les ...  Lyon
# 22   4.826418  L'Hotel Des Remparts Perrache vous accueille à...  Lyon
# 23   4.831922  L'Hôtel du Théâtre vous accueille dans le cent...  Lyon
# 24   4.831781  Doté d’une connexion Wi-Fi gratuite et install...  Lyon
#
#     latitude_city  longitude_city   temp  rain
# 0       45.757814        4.832011  17.15  2.05
# 1       45.757814        4.832011  17.15  2.05
# 2       45.757814        4.832011  17.15  2.05
# 3       45.757814        4.832011  17.15  2.05
# 4       45.757814        4.832011  17.15  2.05
# 5       45.757814        4.832011  17.15  2.05
# 6       45.757814        4.832011  17.15  2.05
# 7       45.757814        4.832011  17.15  2.05
# 8       45.757814        4.832011  17.15  2.05
# 9       45.757814        4.832011  17.15  2.05
# 10      45.757814        4.832011  17.15  2.05
# 11      45.757814        4.832011  17.15  2.05
# 12      45.757814        4.832011  17.15  2.05
# 13      45.757814        4.832011  17.15  2.05
# 14      45.757814        4.832011  17.15  2.05
# 15      45.757814        4.832011  17.15  2.05
# 16      45.757814        4.832011  17.15  2.05
# 17      45.757814        4.832011  17.15  2.05
# 18      45.757814        4.832011  17.15  2.05
# 19      45.757814        4.832011  17.15  2.05
# 20      45.757814        4.832011  17.15  2.05
# 21      45.757814        4.832011  17.15  2.05
# 22      45.757814        4.832011  17.15  2.05
# 23      45.757814        4.832011  17.15  2.05
# 24      45.757814        4.832011  17.15  2.05
