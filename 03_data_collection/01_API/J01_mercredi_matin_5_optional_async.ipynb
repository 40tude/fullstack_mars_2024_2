# %% [markdown]
# # Asynchronous programming for faster speed!
#
# Imagine you are working in an assembly line where your job is to stick a logo on a product, this task takes very little time like 1 minute, but the task happening right before you is building the product which takes 1 hour. You could be sticking logos on 60 products and hour, but you have to wait for each product to be finished first. It would be great if you could build several products at the same time so you could be as productive as you could right?!
#
# Well, this exactly what Asynchronous tasks will help you with!

# %% [markdown]
# ## What you are going to learn in this course 🧐🧐
#
# This course will teach you how to make asynchronous code using the `asyncio` library, which is one of the most popular out there! Let's give the outline:
#
# * What is asynchronous programming?
# * Why do we need asynchronous programming?

# %% [markdown]
# ## What is asynchronous programming?
#
# Asynchronous programming is a type of parallel programming in which a unit of work is allowed to run separately from the primary application thread. When the work is complete, it notifies the main thread about completion or failure of the worker thread. There are numerous benefits to using it, such as improved application performance and enhanced responsiveness.
#
# What this sentence means is that the asynchronous piece of code will run, but it will not block the rest of the code from running, the various tasks will be able to run simultaneously (we also say in parallel).
#
# This great when some tasks take longer than others, and when different parts of your code can be executed independently from each other without failing!

# %% [markdown]
# ## Why do we need asynchronous programming?
#
# As you will start coding more and more and get experience in the field of data science, you will learn to remember that data science stands at the crossroad of statistics and computer science. And who says computer science says, well computers!
#
# We'll get back to this in future lectures but it is important to have in mind that when dealing with computers, we are using physical elements to make calculations for us and transmit data to each other etc and these operations take time. Let's take a look at different execution times per operations for various elements of a computer:
#
# > Remember that there is a "computer" in "computer science".
# — Peter Norvig
#
# - CPU (Central Processing Unit) ≈ 1 ns
# - Memory ≈ 100 ns
# - Disk ≈ 20 μs
# - Network ≈ 150 ms
#
# Now let's imagine we are trying to make many API calls (wild, I know) in a loop over a list of urls. What will happen is the following:
#
# 1. Enter the loop code (CPU)
# 2. Get data to write the query from the url list (Memory)
# 3. Send query (Network)
# 4. Wait for query response (Network)
# 5. Save response (Memory)
# 6. Go to next step of the loop (CPU)
#
# The amount of time we spend waiting for to receive the API's response is much longer than any of the other operations (we could be sticking lots of logos but we are waiting for the products to be ready), causing the whole process to be super slow.
#
# Now if we make the part of the code that deals with the API asychronous, then we do not have to wait for the API to respond to start sending new queries, causing the total execution time of the loop to be much quicker! This works because most APIs are running on machines that can process several calls in parallel!

# %% [markdown]
# ## Asynchronous programming
#
# Let's move on to practice! We will start by giving generic examples to explain the basics of asynchronoujs programming, then we will give more concrete examples of how it works when using loops in which we expect down time periods, then a quick demonstration with an actual API.

# %% [markdown]
# ### Synchronous program
#
# Notebooks are very useful for trying things and exploring data, however, when writing programs to call API and fill databases etc.. we rarely use them. Instead data scientists, and more generally developpers write scripts (.py files) that contain python code all in one block!
#
# [This first program](src/async1.py) only uses synchronous processes and therefore every task happens one after the other like we are used to.

# %%
# !python src/async1.py # this will execute the python file async1.py in the src folder!
# Out:
# Hello!
# Goodbye!

# %% [markdown]
# ### Our first asynchronous program
#
# Let's introduce the `asyncio` library, which let's python run asynchronous programs! The program can be found [here](src/async2.py).

# %%
# !python src/async2.py
# Out:
# src/async2.py:6: RuntimeWarning: coroutine 'main' was never awaited
#   main()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Goodbye!

# %% [markdown]
# Here we see that the final statement of our program was executed, however the `main()` function was never executed, and the error states the reason for that is we never awaited for this program to run!
#
# Indeed, when defining an asynchronous program with the keyword `async` it turns the function `main()` into what we call a **coroutine** that works a little bit differently than regular functions. If we want this coroutine to actually run we need to use the `asyncio.run` method, like we do in [this program](src/async3.py).

# %%
# !python src/async3.py
# Out:
# Hello!
# Goodbye!

# %% [markdown]
# Now everything works fine! But we have'nt done anything more than running the two processes one after the other, which is not the goal of asynchronous programming. What we want is to be able to run various tasks simultaneously while others are inactive!
#
# Using the `asyncio.run` method is actually creating what we call and **event loop** which is sort of a timeline where the system in which you are running your code will decide which program to actively run depending on what program can be immediatly active and which one is waiting on some other thing to finish.

# %% [markdown]
# ### Waiting for other tasks to finish
#
# In [this program](src/async4.py), we will show you how the event loop works by creating asynchronous **tasks** that we wish to run concurrently. Notice that we are using the keyword **await** which executes a coroutine inside an asynchronous function, this keyword cannot be used outside of such a function.

# %%
# !python src/async4.py
# Out:
# OK
# Goodbye!
# Hello!

# %% [markdown]
# Here the function `bye()` starts by waiting for one second, which means that for one second the processor is doing nothing! Ideally we would like to take advantage of that down time to continue running the rest of the `main()` function! Which is the point of asynchronous programming!

# %% [markdown]
# ### Taking advantage of other tasks' downtime
#
# In order to take advantage of the downtime of some processes to run others we need to create a task using `asyncio.create_task` (how very original right!?), which will indicate python that a certain piece of program may take some time doing nothing because it is waiting for, let's say, an API to return some results, and that in the meantime it can move on with the execution of other processes.
#
# [This program](src/async5.py) will show you how we can do this.

# %%
# !python src/async5.py
# Out:
# Hello!
# OK

# %% [markdown]
# So here, we execute `main()` without having to wait for `bye()` to finish, which means that `bye()` will run whenever `main()` stops trusting the processor. In this case `bye()` is able to print `OK` but while it's waiting for 1 second, `main()` is actually done so the execution stops before `bye()` can finish.
#
# In the [following example](src/async6.py) we will show you how the two different asynchronous programs can alternate waiting for each other.

# %%
# !python src/async6.py
# Out:
# Hello!
# OK
# Goodbye!

# %% [markdown]
# Now because we force `main()` to wait for 2 seconds, it gives enough time for `bye()` to actually keep on running and finish!
#
# To summarize, the `await` keyword is essential because it tells python when the execution may move from a process to the other process.

# %% [markdown]
# ### Making asynchronous loops and saving results
#
# If you are trying to run many different tasks in a loop and want more tasks to get started as other ones are waiting and get all the results at the end you may use `asyncio.gather` which will return and aggregate list of all the results given by the asynchronous processes!
#
# Let's take a look at [this example](src/async7.py) for an application demo.

# %%
import asyncio
from src.async7 import main
import time
import src.config # the configuration file so the logs from our asynchronous code be displayed
loop = asyncio.get_event_loop()

start = time.time()
task = loop.create_task(main())
end = time.time()
print(end - start)
# Out:
# 0.00012493133544921875
# [2022-01-12 13:17:16 UTC]	INFO	Starting query...	(src.async7)
# [2022-01-12 13:17:18 UTC]	INFO	The process took 2.0041871070861816 seconds	(src.async7)

# %%
task.result()
# Out:
# ['response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response',
#  'response']

# %% [markdown]
# In this example we simulate 100 API calls that should take 2 seconds each. If we had executed this synchronously it would have taken at least 200 seconds to run. Using asynchronous programming the process only took a little more than 2 seconds because all the tasks could be executed simultaneously!
#
# This will be extremely useful when querying APIs to get massive amounts of data!

# %% [markdown]
# ### Applied example
#
# This [last example](src/async8.py) will give you an applied example of asynchronous API calls on the teleport API.
# We'll have to introduce a new library to make the HTTP requets asynchronous as well (so they work a little bit like `asyncio.sleep` commands)
#
# This library that lets you make asynchronous HTTP requests is called `tornado` and we will use its `AsyncHTTPClient` method. Find more documentation on this [here](https://www.tornadoweb.org/en/stable/httpclient.html#).

# %%
import asyncio
from src.async8 import search
import time
import src.config # the configuration file so the logs from our asynchronous code be displayed
loop = asyncio.get_event_loop()

cities = ["Tokyo",
"Delhi",
"Shanghai",
"Sao Paulo",
"Mexico City",
"Cairo",
"Mumbai",
"Beijing",
"Dhaka",
"Osaka",
"New York",
"Karachi",
"Buenos Aires",
"Chongqing",
"Istanbul",
"Kolkata",
"Manila",
"Lagos",
"Rio de Janeiro",
"Tianjin",
"Kinshasa",
"Guangzhou",
"Los Angeles",
"Moscow",
"Shenzhen",
"Lahore",
"Bangalore",
"Paris",
"Bogota",
"Jakarta",
"Chennai",
"Lima",
"Bangkok",
"Seoul",
"Nagoya",
"Hyderabad",
"London",
"Tehran",
"Chicago",
"Chengdu",
"Nanjing",
"Wuhan",
"Ho Chi Minh City",
"Luanda",
"Ahmedabad",
"Kuala Lumpur",
"Xi'an",
"Hong Kong",
"Dongguan",
"Hangzhou",
"Foshan",
"Shenyang",
"Riyadh",
"Baghdad",
"Santiago",
"Surat",
"Madrid",
"Suzhou",
"Pune",
"Harbin",
"Houston",
"Dallas",
"Toronto",
"Dar es Salaam",
"Miami",
"Belo Horizonte",
"Singapore",
"Philadelphia",
"Atlanta",
"Fukuoka",
"Khartoum",
"Barcelona",
"Johannesburg",
"Saint Petersburg",
"Qingdao",
"Dalian",
"Washington, D.C.",
"Yangon",
"Alexandria",
"Jinan",
"Guadalajara"]

cities = [city.replace(" ","%20") for city in cities]
print(cities[:5])

start = time.time()
task = loop.create_task(search(cities))
end = time.time()
print(end - start)
# Out:
# ['Tokyo', 'Delhi', 'Shanghai', 'Sao%20Paulo', 'Mexico%20City']
# 0.0001010894775390625
# [2022-01-12 14:48:55 UTC]	INFO	Starting query...	(src.async8)
# [2022-01-12 14:49:08 UTC]	INFO	The process took 13.323923110961914 seconds	(src.async8)

# %%
task.result()
# Out:
# [{'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1850147/'}},
#      'matching_alternate_names': [{'name': 'Tokyo'}, {'name': 'tokyo'}],
#      'matching_full_name': 'Tokyo, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1863440/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Hachiōji, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1857871/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Machida, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1864518/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Chōfu, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1850692/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Nishi-Tokyo-shi, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1860437/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kamirenjaku, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1862599/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Hino, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7279570/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Higashimurayama, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1854162/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Ōme, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1849186/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Urayasu, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1856367/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Musashino, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1858964/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kokubunji, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1850693/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tanashichō, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1907148/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Fussa, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1861261/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Itsukaichi, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611487/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tachikawa, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611617/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kunitachi, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611618/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Miyake, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611619/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Hachijō, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611620/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Ōshima, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11611621/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Ogasawara, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:6822129/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tama, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:6822130/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Musashimurayama, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:6822132/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Akishima, Tokyo, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:6822136/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Higashiyamato, Tokyo, Japan'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Tokyo&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1273294/'}},
#      'matching_alternate_names': [{'name': 'Delhi'}, {'name': 'Delhio'}],
#      'matching_full_name': 'Delhi, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1645457/'}},
#      'matching_alternate_names': [{'name': 'Delhi'}],
#      'matching_full_name': 'Dili, Díli, East Timor (Delhi)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5342522/'}},
#      'matching_alternate_names': [{'name': 'Delhi'}],
#      'matching_full_name': 'Delhi, California, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1267696/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Karol Bāgh, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1261481/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'New Delhi, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4050006/'}},
#      'matching_alternate_names': [{'name': 'Delhi Hills'}],
#      'matching_full_name': 'Delhi Hills, Ohio, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1261913/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Nāngloi Jāt, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5114824/'}},
#      'matching_alternate_names': [{'name': 'Delhi'}],
#      'matching_full_name': 'Delhi, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4321929/'}},
#      'matching_alternate_names': [{'name': 'Delhi'},
#       {'name': 'Delhi (Louisiana)'}],
#      'matching_full_name': 'Delhi, Louisiana, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:10263232/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Deoli, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1276663/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Bawāna, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1279005/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Alīpur, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7290413/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Pitampura, NCT, India'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1281378/'}},
#      'matching_alternate_names': [{'name': 'Delhi'}],
#      'matching_full_name': 'Delingha, Qinghai, China (Delhi)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Delhi&geohash='}},
#   'count': 14},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1796236/'}},
#      'matching_alternate_names': [{'name': 'Shanghai'},
#       {'name': 'Shanghai - shang hai'},
#       {'name': 'Shanghai - 上海'}],
#      'matching_full_name': 'Shanghai, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1794035/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Songjiang, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1783920/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Zhujiajiao, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1801696/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Luwan, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1808090/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Hongkou, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1815611/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Changning, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1816917/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Baoshan, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7845495/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Xiayang, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7845524/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Xinchenglu, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7846104/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Fangsong, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1787375/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Yangpu, Shanghai, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1787957/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Xuhui, Shanghai, China'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Shanghai&geohash='}},
#   'count': 12},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3448439/'}},
#      'matching_alternate_names': [{'name': 'Sao Paulo'},
#       {'name': 'Sao Paulo capital'}],
#      'matching_full_name': 'São Paulo, São Paulo, Brazil (Sao Paulo)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2240449/'}},
#      'matching_alternate_names': [{'name': 'Sao Paulo da Assuncao de Luanda'},
#       {'name': 'Sao Paulo de Loanda'},
#       {'name': 'Sao Paulo de Luanda'}],
#      'matching_full_name': 'Luanda, Luanda, Angola (Sao Paulo da Assuncao de Luanda)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3662252/'}},
#      'matching_alternate_names': [{'name': 'Sao Paulo de Olivenca'}],
#      'matching_full_name': 'São Paulo de Olivença, Amazonas, Brazil (Sao Paulo de Olivenca)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3388238/'}},
#      'matching_alternate_names': [{'name': 'Sao Paulo do Potengi'}],
#      'matching_full_name': 'São Paulo do Potengi, Rio Grande do Norte, Brazil (Sao Paulo do Potengi)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3462944/'}},
#      'matching_alternate_names': [{'name': 'Sao Paulo'}],
#      'matching_full_name': 'Frei Paulo, Sergipe, Brazil (Sao Paulo)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Sao%20Paulo&geohash='}},
#   'count': 5},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3530597/'}},
#      'matching_alternate_names': [{'name': 'Mexico City'}],
#      'matching_full_name': 'Mexico City, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3526683/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Iztapalapa, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3514674/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Gustavo Adolfo Madero, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3514663/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Álvaro Obregón, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3530139/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Coyoacán, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3515428/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tlalpan, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3827409/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Cuauhtémoc, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3827407/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Venustiano Carranza, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3532497/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Azcapotzalco, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3514450/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Xochimilco, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3526700/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Iztacalco, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3827406/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Benito Juarez, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3827408/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Miguel Hidalgo, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3515463/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tláhuac, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7280708/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Colonia del Valle, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3523760/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Magdalena Contreras, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3530049/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Delegación Cuajimalpa de Morelos, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3523202/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Milpa Alta, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7280718/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Colonia Nativitas, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3521305/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Polanco, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8858100/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'San Antonio Tecómitl, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3827403/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'San Lorenzo Acopilco, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7280712/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Col. Bosques de las Lomas, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8858142/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'San Francisco Tecoxpa, Mexico City, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8859188/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Lomas de Tepemecatl, Mexico City, Mexico'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Mexico%20City&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:360630/'}},
#      'matching_alternate_names': [{'name': 'Cairo'},
#       {'name': 'Cairo - alqahrt'},
#       {'name': 'Cairo - القاهرة'}],
#      'matching_full_name': 'Cairo, Cairo, Egypt'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4185632/'}},
#      'matching_alternate_names': [{'name': 'Cairo'}],
#      'matching_full_name': 'Cairo, Georgia, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3181259/'}},
#      'matching_alternate_names': [{'name': 'Cairo Montenotte'}],
#      'matching_full_name': 'Cairo Montenotte, Liguria, Italy'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:355795/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Ḩalwān, Cairo, Egypt'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7799991/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'New Cairo, Cairo, Egypt'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4234985/'}},
#      'matching_alternate_names': [{'name': 'Cairo'}],
#      'matching_full_name': 'Cairo, Illinois, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3029178/'}},
#      'matching_alternate_names': [{'name': 'Cairon'}],
#      'matching_full_name': 'Cairon, Normandy, France'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5111056/'}},
#      'matching_alternate_names': [{'name': 'Cairo'}],
#      'matching_full_name': 'Cairo, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3181261/'}},
#      'matching_alternate_names': [{'name': 'Cairo'}],
#      'matching_full_name': 'Caira, Latium, Italy (Cairo)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3180577/'}},
#      'matching_alternate_names': [{'name': 'Caironega'}],
#      'matching_full_name': 'Caravonica, Liguria, Italy (Caironega)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Cairo&geohash='}},
#   'count': 10},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1275339/'}},
#      'matching_alternate_names': [{'name': 'mumbai'},
#       {'name': 'Mumbai'},
#       {'name': 'Mumbai - मुम़बई'}],
#      'matching_full_name': 'Mumbai, Maharashtra, India'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Mumbai&geohash='}},
#   'count': 1},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1816670/'}},
#      'matching_alternate_names': [{'name': 'Beijing'},
#       {'name': 'beijing'},
#       {'name': 'Beijing Shi'}],
#      'matching_full_name': 'Beijing, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2656192/'}},
#      'matching_alternate_names': [{'name': 'beijingusutoku'}],
#      'matching_full_name': 'Basingstoke, England, United Kingdom (beijingusutoku)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1800657/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Mentougou, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1792520/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tongzhou, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2034754/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Shunyi, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1807544/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Daxing, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1811542/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Fangshan, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2038154/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Changping, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1803948/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Liangxiang, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389504/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Jinrongjie, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389511/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Chaowai, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389516/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Gongchen, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389517/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Beiyuan, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389518/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Shengli, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389519/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Xingfeng, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389520/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Binhe, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389521/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Gulou, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8541175/'}},
#      'matching_alternate_names': [{'name': 'Beijinglu'},
#       {'name': 'Beijinglu Jiedao'}],
#      'matching_full_name': 'Beijinglu, Anhui, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:9275963/'}},
#      'matching_alternate_names': [{'name': 'Beijinglu'}],
#      'matching_full_name': 'Beijinglu, Xinjiang, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1809104/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Haidian, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1811227/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Fengtai, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2033458/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Yanqing, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8388017/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Chengbei, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8388863/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Longshan, Beijing, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8389413/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Dayu, Beijing, China'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Beijing&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185241/'}},
#      'matching_alternate_names': [{'name': 'Dhaka'}, {'name': 'dhaka'}],
#      'matching_full_name': 'Dhaka, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1273043/'}},
#      'matching_alternate_names': [{'name': 'Dhaka'}],
#      'matching_full_name': 'Dhāka, Bihar, India (Dhaka)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185098/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tungi, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185117/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Narsingdi, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185159/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Nāgarpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185155/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Nārāyanganj, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:9827976/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Paltan, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1336144/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tāngāil, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1187530/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Sonārgaon, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1203344/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Farīdpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185263/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Bhairab Bāzār, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:7701354/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Azimpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1337249/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kishorganj, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1337245/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Mādārīpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1191368/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Pālang, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185920/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Tungipāra, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11609988/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Joymontop, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185100/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Dohār, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185165/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Mirzāpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1189056/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Sakhipur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1185276/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Bājitpur, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1207047/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Char Bhadrāsan, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11609984/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Parvez Ali Family, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11609643/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Parvez Ali Hossain, Dhaka, Bangladesh'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11609980/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Khanbaniara, Dhaka, Bangladesh'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Dhaka&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1853909/'}},
#      'matching_alternate_names': [{'name': 'Osaka'},
#       {'name': 'osaka'},
#       {'name': 'osaka si'},
#       {'name': 'Osaka-shi'}],
#      'matching_full_name': 'Osaka, Ōsaka, Japan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1520327/'}},
#      'matching_alternate_names': [{'name': 'Osakarovka'}],
#      'matching_full_name': 'Osakarovka, Karaganda, Kazakhstan'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3354021/'}},
#      'matching_alternate_names': [{'name': 'Osakatis'}],
#      'matching_full_name': 'Oshakati, Oshana, Namibia (Osakatis)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:616320/'}},
#      'matching_alternate_names': [{'name': 'Osakan'}],
#      'matching_full_name': 'Oshakan, Aragatsotn, Armenia (Osakan)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:11612568/'}},
#      'matching_alternate_names': [{'name': 'Osaka-sayama'}],
#      'matching_full_name': 'Ōsaka-sayama, Ōsaka, Japan (Osaka-sayama)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Osaka&geohash='}},
#   'count': 5},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5128581/'}},
#      'matching_alternate_names': [{'name': 'New York'},
#       {'name': 'New York borg'},
#       {'name': 'New York City'},
#       {'name': 'New York kenti'},
#       {'name': 'New York Stad'},
#       {'name': 'New York-borg'},
#       {'name': 'New Yorke'},
#       {'name': 'New Yorku'}],
#      'matching_full_name': 'New York City, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5110302/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Brooklyn, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5133273/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Queens, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5125771/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Manhattan, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5110266/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'The Bronx, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5383465/'}},
#      'matching_alternate_names': [{'name': 'New York of the Pacific'}],
#      'matching_full_name': 'Pittsburg, California, United States (New York of the Pacific)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5139568/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Staten Island, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5110629/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Buffalo, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5122520/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Jamaica, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5134086/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Rochester, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5145215/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Yonkers, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5120034/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Harlem, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5115843/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'East Flatbush, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5115985/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'East New York, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5128616/'}},
#      'matching_alternate_names': [{'name': 'New York Mills'},
#       {'name': 'New York Upper Mills'}],
#      'matching_full_name': 'New York Mills, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5143307/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Washington Heights, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5107464/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Astoria, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5109790/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Borough Park, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5140405/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Syracuse, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8436486/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Sunset Park, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5137849/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Sheepshead Bay, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5107129/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Amherst, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:6332428/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'East Harlem, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5116495/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Elmhurst, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5110918/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Bushwick, New York, United States'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=New%20York&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1174872/'}},
#      'matching_alternate_names': [{'name': 'karachi'},
#       {'name': 'Karachi'},
#       {'name': 'Karachi - krachy'},
#       {'name': 'Karachi - كراچى'}],
#      'matching_full_name': 'Karachi, Sindh, Pakistan'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Karachi&geohash='}},
#   'count': 1},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3435910/'}},
#      'matching_alternate_names': [{'name': 'Buenos Aires'}],
#      'matching_full_name': 'Buenos Aires, Buenos Aires F.D., Argentina'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3432043/'}},
#      'matching_alternate_names': [],
# ...
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Saint%20Petersburg&geohash='}},
#   'count': 25},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1797929/'}},
#      'matching_alternate_names': [{'name': 'Qingdao'},
#       {'name': 'Qingdao Shi'}],
#      'matching_full_name': 'Qingdao, Shandong, China'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Qingdao&geohash='}},
#   'count': 1},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1814087/'}},
#      'matching_alternate_names': [{'name': 'Dalian'}, {'name': 'Dalian Shi'}],
#      'matching_full_name': 'Dalian, Liaoning, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1814082/'}},
#      'matching_alternate_names': [{'name': 'Daliang'},
#       {'name': 'Daliang Jiedao'}],
#      'matching_full_name': 'Daliang, Guangdong, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1921372/'}},
#      'matching_alternate_names': [{'name': 'Dalianwan'}],
#      'matching_full_name': 'Dalianwan, Liaoning, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1814078/'}},
#      'matching_alternate_names': [{'name': 'Daliang'}],
#      'matching_full_name': 'Daliang, Tianjin, China'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Dalian&geohash='}},
#   'count': 4},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4140963/'}},
#      'matching_alternate_names': [{'name': 'Washington'},
#       {'name': 'Washington City'},
#       {'name': 'Washington D. C.'},
#       {'name': 'Washington D.C.'},
#       {'name': 'Washington DC'},
#       {'name': 'Washington'},
#       {'name': ' D.C.'}],
#      'matching_full_name': 'Washington, D.C., Washington, D.C., United States'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Washington,%20D.C.&geohash='}},
#   'count': 1},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1298824/'}},
#      'matching_alternate_names': [{'name': 'Yangon'}, {'name': 'yangon'}],
#      'matching_full_name': 'Yangon, Yangon, Myanmar'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1295395/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Syriam, Yangon, Myanmar'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1320944/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kanbe, Yangon, Myanmar'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1291193/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Thongwa, Yangon, Myanmar'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1290374/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Twante, Yangon, Myanmar'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1319533/'}},
#      'matching_alternate_names': [],
#      'matching_full_name': 'Kayan, Yangon, Myanmar'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Yangon&geohash='}},
#   'count': 6},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:361058/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'},
#       {'name': 'Alexandria Magna'}],
#      'matching_full_name': 'Alexandria, Alexandria, Egypt'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4744091/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'},
#       {'name': 'Alexandria City'}],
#      'matching_full_name': 'Alexandria, Virginia, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:686502/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'},
#       {'name': 'Alexandria i Romania'}],
#      'matching_full_name': 'Alexandria, Teleorman, Romania'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4314550/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Louisiana, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:311111/'}},
#      'matching_alternate_names': [{'name': 'Alexandria ad Issum'}],
#      'matching_full_name': 'İskenderun, Hatay, Turkey (Alexandria ad Issum)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3183299/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alessandria, Piedmont, Italy (Alexandria)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5016108/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Minnesota, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3407977/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Rio Grande do Norte, Brazil'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4282342/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Kentucky, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2657513/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Scotland, United Kingdom'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4917537/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Indiana, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:2178136/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, New South Wales, Australia'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4829861/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, Alabama, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:736929/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexándreia, Central Macedonia, Greece (Alexandria)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4527963/'}},
#      'matching_alternate_names': [{'name': 'Alexandriaville'}],
#      'matching_full_name': 'West Carrollton City, Ohio, United States (Alexandriaville)'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3491593/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, St Ann, Jamaica'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5082573/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, New Hampshire, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5106950/'}},
#      'matching_alternate_names': [{'name': 'Alexandria Bay'}],
#      'matching_full_name': 'Alexandria Bay, New York, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5225919/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Alexandria, South Dakota, United States'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5098303/'}},
#      'matching_alternate_names': [{'name': 'Alexandria'}],
#      'matching_full_name': 'Frenchtown, New Jersey, United States (Alexandria)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Alexandria&geohash='}},
#   'count': 20},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1805753/'}},
#      'matching_alternate_names': [{'name': 'Jinan'},
#       {'name': 'Jinan Shi'},
#       {'name': 'jinan si'},
#       {'name': 'jinana'}],
#      'matching_full_name': 'Jinan, Shandong, China'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1846114/'}},
#      'matching_alternate_names': [{'name': 'Jinan-gun'}],
#      'matching_full_name': 'Jinan-gun, Jeollabuk-do, South Korea'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Jinan&geohash='}},
#   'count': 2},
#  {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:4005539/'}},
#      'matching_alternate_names': [{'name': 'Guadalajara'},
#       {'name': 'Guadalajara i Jalisco'}],
#      'matching_full_name': 'Guadalajara, Jalisco, Mexico'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3121070/'}},
#      'matching_alternate_names': [{'name': 'Guadalajara'}],
#      'matching_full_name': 'Guadalajara, Castille-La Mancha, Spain'},
#     {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3688256/'}},
#      'matching_alternate_names': [{'name': 'Guadalajara de Buga'}],
#      'matching_full_name': 'Buga, Valle del Cauca, Colombia (Guadalajara de Buga)'}]},
#   '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#      'name': 'location',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#      'name': 'city',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#      'name': 'ua',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#      'name': 'country',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#      'name': 'a1',
#      'templated': True},
#     {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#      'name': 'tz',
#      'templated': True}],
#    'self': {'href': 'https://api.teleport.org/api/cities/?search=Guadalajara&geohash='}},
#   'count': 3}]

# %% [markdown]
# Let's now do the same thing using synchronous programming!

# %%
import requests

cities = ["Tokyo",
"Delhi",
"Shanghai",
"Sao Paulo",
"Mexico City",
"Cairo",
"Mumbai",
"Beijing",
"Dhaka",
"Osaka",
"New York",
"Karachi",
"Buenos Aires",
"Chongqing",
"Istanbul",
"Kolkata",
"Manila",
"Lagos",
"Rio de Janeiro",
"Tianjin",
"Kinshasa",
"Guangzhou",
"Los Angeles",
"Moscow",
"Shenzhen",
"Lahore",
"Bangalore",
"Paris",
"Bogota",
"Jakarta",
"Chennai",
"Lima",
"Bangkok",
"Seoul",
"Nagoya",
"Hyderabad",
"London",
"Tehran",
"Chicago",
"Chengdu",
"Nanjing",
"Wuhan",
"Ho Chi Minh City",
"Luanda",
"Ahmedabad",
"Kuala Lumpur",
"Xi'an",
"Hong Kong",
"Dongguan",
"Hangzhou",
"Foshan",
"Shenyang",
"Riyadh",
"Baghdad",
"Santiago",
"Surat",
"Madrid",
"Suzhou",
"Pune",
"Harbin",
"Houston",
"Dallas",
"Toronto",
"Dar es Salaam",
"Miami",
"Belo Horizonte",
"Singapore",
"Philadelphia",
"Atlanta",
"Fukuoka",
"Khartoum",
"Barcelona",
"Johannesburg",
"Saint Petersburg",
"Qingdao",
"Dalian",
"Washington, D.C.",
"Yangon",
"Alexandria",
"Jinan",
"Guadalajara"]

cities = [city.replace(" ","%20") for city in cities]
print(cities[:5])

result = {}
start = time.time()
for city in cities:
    url = f"https://api.teleport.org/api/cities/?search={city}"
    r = requests.get(url)
    result[city] = r.json()
end = time.time()
print(end - start)
# Out:
# ['Tokyo', 'Delhi', 'Shanghai', 'Sao%20Paulo', 'Mexico%20City']
# 12.797714233398438

# %% [markdown]
# Synchronous programming took ten times longer than its asynchronous counterpart.

# %% [markdown]
# ## Ressources
#
# * [Medium article on asynchronous programming](https://medium.com/velotio-perspectives/an-introduction-to-asynchronous-programming-in-python-af0189a88bbb#:~:text=Asynchronous%20programming%20is%20a%20type,failure%20of%20the%20worker%20thread.)
# * [asyncio video tutorial](https://www.youtube.com/watch?v=t5Bo1Je9EmE)
# * [asyncio vs other asyhnchronous programming techniques](https://www.youtube.com/watch?v=bs9tlDFWWdQ)
