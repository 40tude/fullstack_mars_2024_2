# %% [markdown]
# # Extract and store data from YouTube songs
#
# ![song](https://source.unsplash.com/nyBUfH9MkL4)
# Photo by [@mybibimbaplife](https://unsplash.com/@mybibimbaplife)

# %% [markdown]
# ## Guidelines
#
# Open the `02-Extract-and-store-from-Youtube-API.ipynb` notebook, and follow the instructions.
#
# Please, note that the code we wrote for you in this notebook uses the module `src/data_collection.py` to work efficiently. We'd like you to have a look at this module, just to familiarize yourself with lesser-known Python concepts, specifically the `asyncio` package.
#
# Don't panic if you don't understand this module: it takes practice to master those concepts. The goal here is just to give you a first glimpse at what is possible with Python, beyond its "classical" utilization that you see everywhere on the Web.

# %% [markdown]
# ## 1. Objective
#
# The goal of this mini-project is to fetch extra data for all the videos appearing in the Youtube songs playlog dataset. With this exercice, you will learn how to:
#
# - Use the YouTube API
# - Write efficient and asynchronous Python code
# - Create a `boto3` session object to store your AWS credentials
# - Store a big JSON object in AWS S3 using `boto3`
#
# ### Why ?
#
# One of the jobs of the Data Engineer is to be able to collect and store data, so that her fellow Data Scientists and Data Analysts will have enough materials to work efficiently.
#
# The original dataset is interesting, but we need more data about the songs to do an interesting and insightful analysis and/or modelization of the users behaviour.
#
# ### How ?
#
# Luckily for us, in this case there is a simple way to gather data about YouTube videos: the Youtube API!
#
# You now know what is web API and how to make your Python program interact with it. However, the volume of the dataset (more than 630,000 songs!) will force us to be creative in the difficulties we will encounter... Let's go!
#
# ----
#
# ### First steps

# %% [markdown]
# Before anything, we need to have a list of all the songs IDs of the dataset. To achieve this, we will quickly load the data in a `pandas` dataframe, and extract all the unique values in the `song` column.

# %%
# Will be necessary to read the dataset from a public file stored on S3 from pandas
# !pip install s3fs
# Out:
# Requirement already satisfied: s3fs in c:\users\charl\anaconda3\lib\site-packages (2021.11.1)
# Requirement already satisfied: aiohttp<=4 in c:\users\charl\anaconda3\lib\site-packages (from s3fs) (3.8.1)
# Requirement already satisfied: aiobotocore~=2.0.1 in c:\users\charl\anaconda3\lib\site-packages (from s3fs) (2.0.1)
# Requirement already satisfied: fsspec==2021.11.1 in c:\users\charl\anaconda3\lib\site-packages (from s3fs) (2021.11.1)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\users\charl\anaconda3\lib\site-packages (from aiobotocore~=2.0.1->s3fs) (0.8.0)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\charl\anaconda3\lib\site-packages (from aiobotocore~=2.0.1->s3fs) (1.12.1)
# Requirement already satisfied: botocore<1.22.9,>=1.22.8 in c:\users\charl\anaconda3\lib\site-packages (from aiobotocore~=2.0.1->s3fs) (1.22.8)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (5.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\charl\anaconda3\lib\site-packages (from aiohttp<=4->s3fs) (1.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\charl\anaconda3\lib\site-packages (from botocore<1.22.9,>=1.22.8->aiobotocore~=2.0.1->s3fs) (1.26.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\charl\anaconda3\lib\site-packages (from botocore<1.22.9,>=1.22.8->aiobotocore~=2.0.1->s3fs) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\charl\anaconda3\lib\site-packages (from botocore<1.22.9,>=1.22.8->aiobotocore~=2.0.1->s3fs) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\charl\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.9,>=1.22.8->aiobotocore~=2.0.1->s3fs) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\charl\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<=4->s3fs) (3.2)

# %%
# TODO: import pandas
### BEGIN STRIP ###
import pandas as pd
### END STRIP ###

# %%
# TODO: Load the 'youtube-playlog.csv' dataset in a pandas dataframe `df`
# NOTE: it may take some time to complete...
### BEGIN STRIP ###
df = pd.read_csv('s3://full-stack-bigdata-datasets/Big_Data/youtube_playlog.csv')
### END STRIP ###

# %%
# TODO: create a list `song_ids` containing all the IDs of songs contained in the dataset
# WARNING: we don't want duplicates!
### BEGIN STRIP ###
song_ids = df['song'].unique().tolist()
### END STRIP ###

# %%
# TODO: how many songs (or video IDs) do we have in our list?
### BEGIN STRIP ###
len(song_ids)
### END STRIP ###
# Out:
# 631348

# %% [markdown]
# ## 2. Extract data from YouTube Data API
#
#
# The [Youtube Data API](https://developers.google.com/youtube/v3/docs/videos/list) allows us to get information such as statistics about play logs, details on the video category etc...
#
# ### Quick maths
#
# Before proceeding, answer these question (using Python as a calculator).
#
# Considering we need to fetch data about more than 630,000 videos, and that a single API call can fetch information about 50 videos max,
#
# **1. how many API calls (roughly) would be necessary to gather all the data we want?**
#
# Knowing that a single API call to YouTube takes about 2 seconds in average to complete,
#
# **2. how much time is necessary to fetch all the extra data ? Is it doable in a class session like today?**

# %%
# Calculate the 2 variables `required_api_calls` and `time_in_hours`
### BEGIN STRIP ###
required_api_calls = len(song_ids) // 50
time_in_seconds = required_api_calls * 2
time_in_hours = time_in_seconds / 3600
### END STRIP ###

print(f'We need to do {required_api_calls} API calls to fetch all the data.')
print(f'It would take about {time_in_hours:.1f} hours to complete.')
# Out:
# We need to do 12626 API calls to fetch all the data.
# It would take about 7.0 hours to complete.

# %% [markdown]
# -----
#
# ### A brief introduction to concurrency
#
# To avoid spending the entire day waiting for the API calls to do their job, we will leverage a very important concept in Software and Data Engineering: **concurrency** — [Wikipedia](https://en.wikipedia.org/wiki/Concurrency_(computer_science)).
#
# In a nutshell, **concurrency** allows us to run commands _asynchronously_ : launching the next command whereas the previous one has not terminated yet.
#
# #### Two differents types of commands
#
# In a program, a command is considered either being **CPU-bound** — requiring lots of processing and calculation — or **I/O-bound** — having to wait for external inputs or outputs — to finish. This distinction is very important, as it will guide you in choosing the best tool for writing asynchronous code.
#
# In our case here, the command is definitely not CPU intensive, it just has to wait for the YouTube API to respond to our request. Hence, our problem here is said to be **I/O bound**.
#
# In Python, there is an historical way to handle concurrency with I/O-bound tasks, with threads. Since Python 3.5 however, the `asyncio` package has joined the standard library.
#
# Today, we don't ask you to build this asynchronous program yourself, as it would require too much of extra knowledge.
#
# **However, we strongly recommend you to 1) read the code below and the functions it uses, and 2) dig into this topic of asynchronous Python programming when you have some time.**

# %% [markdown]
# ### API quotas
#
# Another problem is raising up: by default, **Google gives you a credit of 10,000 unit-calls a day** on their YouTube Data API. Depending on the amount of data you want to fetch, each API call will cost you more or less units.
#
# Here is the official [quota calculator](https://developers.google.com/youtube/v3/determine_quota_cost). In our case, we need to call the `list` method of the `videos` resource.
#
#
#
# Considering that we would like to grab data about the following parts: `snippet`, `contentDetails`, `status`, `statistics` and `topicDetails`,
#
# **1. how much units does a single call cost?**
#
# **2. Hence, how many of such calls can we make in a one day before reaching the limit sets by Google?**
#
# Considering now that you can grab data from 50 videos per call,
#
# **3. how many videos can you extra data from?**

# %%
# TODO: Open the Quota calculator and find the cost of our API call, knowing all the data we want to fetch.
# Then, calculate the `max_calls` and the `max_videos_count` variables
### BEGIN STRIP ###
COST = 11
QUOTA = 10000
max_calls = QUOTA // COST
max_videos_count = max_calls * 50
### END STRIP ###

print(f'We can perform {max_calls} calls a day before reaching the API limit.')
print(f'That means we can fetch extra data for {max_videos_count} videos per day.')
# Out:
# We can perform 909 calls a day before reaching the API limit.
# That means we can fetch extra data for 45450 videos per day.

# %% [markdown]
# ---
#
# As you just calculate, you won't be able to extract the data for all the 630,000+ videos listed in the dataset in a single day.
#
# Today, you are only going to fetch data from 5,000 videos. Tomorrow, when you need to work with the rest of the data, you could do so by accessing all the data we've fetched for you, and stored on S3. You're welcome :)
#
# But before that, learn how to do it yourself! If you can fetch data from 40,000 videos, fetching data from 630,000 is the same... You would just need to wait 20 days to comply with the API quotas!
#
# When you are done, all you need to do is to push the data you just extracted as a JSON file to an S3 bucket.

# %%
# TODO: Slice the `song_ids` list to keep only 5,000 songs ids: `songs_sample`
### BEGIN STRIP ###
songs_sample = song_ids[:50000]
### END STRIP ###

# %% [markdown]
# ### Get a YouTube API key
#
# Create your personnal YouTube API key by following this [guided tutorial](https://developers.google.com/youtube/v3/getting-started)
#
# When you get your key, export it as an environment variable in your current shell by running the following cell:

# %%
# TODO: write your own API key
YOUTUBE_API_KEY = 'AIzaSyDDKKNgq__t6jeJE5jTdsFh5vFBOZ6PQrI'

import os
os.environ['YOUTUBE_API_KEY'] = YOUTUBE_API_KEY

# %% [markdown]
# Please, note that in the real world, you would **never** write an API key directly in your code!

# %% [markdown]
# ### Making asynchronous calls to the YouTube API
#
# We wrote for you the actual code that will download and save the data fetched from the API. All you need to do is to have a look at the function `fetch_all` from the module `src.data_collection` and then to import it.
#
# **NOTE** If your python version is too low (< 3.5) you probably need to use the function `alt_fetch_all()` instead of `fetch_all()`.

# %%
# TODO: after reviewing the `fetch_all` function, import it to your notebook
from data_collection import fetch_all

# %% [markdown]
# Again, we don't ask you to write the following code yourself, as it is beyond the scope of this course. However, we strongly encourage you to dig the topic of concurrent programming in Python.
#
# If you don't understand what this code does in details, that's OK. Read carrefully the comments.

# %%
import asyncio
loop = asyncio.get_event_loop()

task = loop.create_task(fetch_all(songs_sample, dry_run=False))
# Out:
# [2022-01-05 12:14:12 Paris, Madrid]	INFO	Requesting data for 50000 videos. Please wait...	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:13 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:14 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:15 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:16 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:17 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:18 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:19 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:20 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:21 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:22 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:23 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:24 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:25 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:26 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:27 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:28 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:29 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:30 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:31 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:32 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)
# [2022-01-05 12:14:33 Paris, Madrid]	DEBUG	API call succeeded.	(data_collection)

# %% [markdown]
# ☝️ **Wait for a log message `Done! Fetched data...` to show up before continuing! It may take 10-30 seconds depending on your Internet connection.**
#
# **NOTES**
#
# 1 - Did you notice the timestamps of the debug log messages? Thank to concurrency we are able to perform a dozen of API calls per second!
#
# 2 - Have you heard of logging before? It's an important feature to write maintainable code! Check out the resource at the end of this notebook for further information

# %% [markdown]
# Now that the asynchronous calls are done, we need to extract the result. You can do so by calling the `result()` method on your [task](https://docs.python.org/3/library/asyncio-task.html#asyncio.Task) object. Store it into a `result` variable.
#
# When you have your `result` variable, dump its content into a `json_result` variable: we need th result to be stored as a JSON string.

# %%
import json
# TODO: call the `.result(...)` method on the `task` object.
# Store the result of our API calls in `result` variable
### BEGIN STRIP ###
result = task.result()
### END STRIP ###

# TODO: print how many items are inside the `result` list?
### BEGIN STRIP ###
print(len(result))
### END STRIP ###
# Out:
# ---------------------------------------------------------------------------
# HTTPTimeoutError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15656/31599665.py in <module>
#       3 # Store the result of our API calls in `result` variable
#       4 ### BEGIN STRIP ###
# ----> 5 result = task.result()
#       6 ### END STRIP ###
#       7
#
# ~\OneDrive\Documents\jedha\ressources\code\youtube_api\data_collection.py in fetch_all(ids, dry_run)
#      73         for batch_ids in get_batch(ids)
#      74     ]
# ---> 75     all_data = await asyncio.gather(*tasks)
#      76
#      77     duration = time.time() - start
#
# ~\OneDrive\Documents\jedha\ressources\code\youtube_api\data_collection.py in fetch_batch(ids, http_client, dry_run)
#      50     query = youtube_api.build_query_parameters(ids)
#      51     url = f'{youtube_api.BASE_URL}?{query}'
# ---> 52     resp = await http_client.fetch(url)
#      53     if resp.code != 200:
#      54         try:
#
# HTTPTimeoutError: Timeout in request queue

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15656/2443047140.py in <module>
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %% [markdown]
# As you saw, `result` is a list of objects returned by each API calls.  These objects are represented as Python dictionnary, and really big!
#
# Display the first dictionary of the list.

# %%
# TODO: display the first item to have a feel of the content. The rest is the same, but for other videos.
### BEGIN STRIP ###
result[0]
### END STRIP ###
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '1aMNqcJ3-XytgWjIA7QkDUlHHHs',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'OV2vqB0CW-MV73zLNAxyZ524bds',
#    'id': 't1l8Z6gLPzo',
#    'snippet': {'publishedAt': '2013-07-22T12:09:11Z',
#     'channelId': 'UCUERSOitwgUq_37kGslN96w',
#     'title': 'VOLO. "L\'air d\'un con"',
#     'description': 'Enregistré et mixé par Cyrille PELTIER au "Keen Studio" à Tours.\nMerci à Cyrille PELTIER et au "Keen Studio" à Tours.\nToutes les dates de la tournée sur volo.fr\nLe nouvel album "Sans rire" est sorti le 11 mars 2013.\nVolo était à l\'Olympia le 29 avril dernier et est en tournée dans toute la France.\nLe clip de "Toujours à côté" est sur youtube sur http://www.youtube.com/watch?v=cWCH2dpyw1c : Le premier extrait de l\'album est en playliste sur France Bleue, Europe 1, RFM, RFI, Radio Alouette.\n"Sans rire", autre extrait de l\'album, est en playlist sur Virgin Radio.\n\nSortie digitale de "Toujours à côté"\nhttps://itunes.apple.com/fr/album/toujours-a-cote-single/id570616846\n\nVolo est un duo de frères. Frédéric et Olivier VOLOVITCH. \nAvec un nom de famille qui leur vient d\'un arrière grand-père Ukrainien, nés au milieu d\'une fratrie de 4 enfants, ils grandissent dans la campagne tourangelle dans une famille de profs.\n\nFrédo intègre l\'école de la rue Blanche en tant que comédien en 1992, Olivier le rejoint sur Paris en 1997 où il étudie la philosophie à la Sorbonne.\nLe duo se forme officiellement en 2002.\nEntre les différentes tournées des « Wriggles », dont Frédo est un des membres fondateurs, et Olivier le régisseur général, les deux frangins font leurs premiers concerts. D\'abord et surtout dans des bars où autres Caf\'conc, jusqu\' à la sortie de leur 1er disque en 2005 chez « Opéra Music ».\nDepuis, et en tout, les deux frangins, ont sorti cinq albums. Trois studios, un live acoustique et un best of. \nPeu médiatisé « Volo » est aussi et surtout un groupe de scène qui peut compter sur un public fidèle et grandissant. Produits en live par « Blue Line Productions », on les a vus en tournée dans toute la France, à la Cigale, au Trianon, au Bataclan, à l\'Olympia, aux Francofolies de la Rochelle etc...\nAujourd\'hui, récemment signé chez « Play On », Volo revient avec un nouvel album réalisé par Jean-François Delort sur des arrangements de Florian Dubos et Jocelyn Moze. Ce nouveau disque, attendu dans les bacs début 2013, sera accompagné d\'une tournée qui démarrera cet automne et passera par la Cigale le 23 novembre 2012.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t1l8Z6gLPzo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t1l8Z6gLPzo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t1l8Z6gLPzo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/t1l8Z6gLPzo/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'VOLO',
#     'tags': ['volo',
#      'volovitch',
#      'wriggles',
#      'sans rire',
#      'toujours à côté',
#      'bien zarbos',
#      'en attendant',
#      'blancs manteaux',
#      'jours heureux',
#      'play on',
#      'zaz',
#      'tryo'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'VOLO. "L\'air d\'un con"',
#      'description': 'Enregistré et mixé par Cyrille PELTIER au "Keen Studio" à Tours.\nMerci à Cyrille PELTIER et au "Keen Studio" à Tours.\nToutes les dates de la tournée sur volo.fr\nLe nouvel album "Sans rire" est sorti le 11 mars 2013.\nVolo était à l\'Olympia le 29 avril dernier et est en tournée dans toute la France.\nLe clip de "Toujours à côté" est sur youtube sur http://www.youtube.com/watch?v=cWCH2dpyw1c : Le premier extrait de l\'album est en playliste sur France Bleue, Europe 1, RFM, RFI, Radio Alouette.\n"Sans rire", autre extrait de l\'album, est en playlist sur Virgin Radio.\n\nSortie digitale de "Toujours à côté"\nhttps://itunes.apple.com/fr/album/toujours-a-cote-single/id570616846\n\nVolo est un duo de frères. Frédéric et Olivier VOLOVITCH. \nAvec un nom de famille qui leur vient d\'un arrière grand-père Ukrainien, nés au milieu d\'une fratrie de 4 enfants, ils grandissent dans la campagne tourangelle dans une famille de profs.\n\nFrédo intègre l\'école de la rue Blanche en tant que comédien en 1992, Olivier le rejoint sur Paris en 1997 où il étudie la philosophie à la Sorbonne.\nLe duo se forme officiellement en 2002.\nEntre les différentes tournées des « Wriggles », dont Frédo est un des membres fondateurs, et Olivier le régisseur général, les deux frangins font leurs premiers concerts. D\'abord et surtout dans des bars où autres Caf\'conc, jusqu\' à la sortie de leur 1er disque en 2005 chez « Opéra Music ».\nDepuis, et en tout, les deux frangins, ont sorti cinq albums. Trois studios, un live acoustique et un best of. \nPeu médiatisé « Volo » est aussi et surtout un groupe de scène qui peut compter sur un public fidèle et grandissant. Produits en live par « Blue Line Productions », on les a vus en tournée dans toute la France, à la Cigale, au Trianon, au Bataclan, à l\'Olympia, aux Francofolies de la Rochelle etc...\nAujourd\'hui, récemment signé chez « Play On », Volo revient avec un nouvel album réalisé par Jean-François Delort sur des arrangements de Florian Dubos et Jocelyn Moze. Ce nouveau disque, attendu dans les bacs début 2013, sera accompagné d\'une tournée qui démarrera cet automne et passera par la Cigale le 23 novembre 2012.'}},
#    'contentDetails': {'duration': 'PT3M33S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '224219',
#     'likeCount': '1044',
#     'dislikeCount': '27',
#     'favoriteCount': '0',
#     'commentCount': '38'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '-qax5Jz4jQgb-1253zGBkDOmH-I',
#    'id': 'we5gzZq5Avg',
#    'snippet': {'publishedAt': '2012-03-17T08:34:30Z',
#     'channelId': 'UCson549gpvRhPnJ3Whs5onA',
#     'title': 'Julian Jeweil - Air Conditionné',
#     'description': 'Air Conditionné EP',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/we5gzZq5Avg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/we5gzZq5Avg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/we5gzZq5Avg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/we5gzZq5Avg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/we5gzZq5Avg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'LongWayToDream',
#     'tags': ['mnml', 'minimal', 'electronic', 'music'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Julian Jeweil - Air Conditionné',
#      'description': 'Air Conditionné EP'}},
#    'contentDetails': {'duration': 'PT7M46S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '13440',
#     'likeCount': '125',
#     'dislikeCount': '3',
#     'favoriteCount': '0',
#     'commentCount': '2'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'tH85l8CF32tjoTqTRPBxCA4Vbvs',
#    'id': '49esza4eiK4',
#    'snippet': {'publishedAt': '2007-09-08T02:02:07Z',
#     'channelId': 'UCcHYZ8Ez4gG_2bHEuBL8IfQ',
#     'title': 'Justice - D.A.N.C.E',
#     'description': "myspace.com/etjusticepourtous\r\n(Downtown / Ed Banger)\r\n\r\nNominated for MTV VMA video of the year \r\n\r\nFrom the album 'Cross'",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/49esza4eiK4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/49esza4eiK4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/49esza4eiK4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Downtown Records',
#     'tags': ['Justice', 'D.A.N.C.E', 'downtown'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Justice - D.A.N.C.E',
#      'description': "myspace.com/etjusticepourtous\r\n(Downtown / Ed Banger)\r\n\r\nNominated for MTV VMA video of the year \r\n\r\nFrom the album 'Cross'"}},
#    'contentDetails': {'duration': 'PT3M7S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '10108709',
#     'likeCount': '25551',
#     'dislikeCount': '781',
#     'favoriteCount': '0',
#     'commentCount': '3165'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/02lkt',
#      '/m/04rlf',
#      '/m/02lkt'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Electronic_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'CzeSvKU2hJdlonuQTwE1vfTUj98',
#    'id': 'BoO6LfR7ca0',
#    'snippet': {'publishedAt': '2014-01-24T12:52:38Z',
#     'channelId': 'UCQ0wLCF7u23gZKJkHFs1Tpg',
#     'title': 'Gramatik - Torture (feat. Eric Krasno)',
#     'description': '♫ Music Is Our Drug - Spotify Playlist: https://goo.gl/rJvM5l\n►Follow us on Spotify: https://goo.gl/HqOgkN\n\nTorture from the new Gramatik album - The Age Of Reason!\nGramatik:\nhttps://soundcloud.com/gramatik\nhttps://www.facebook.com/gramatik\n\nImage:\nhttp://www.allwalls.net/wallpapers/2012/09/Women-Graffiti-Stadium-Bracelets-1800x2880.jpg\n\n(If any producer or label has an issue with any of the uploads please get in contact with me on YouTube and I will delete it as soon as possible (this includes artists of the images used).',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BoO6LfR7ca0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BoO6LfR7ca0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BoO6LfR7ca0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BoO6LfR7ca0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BoO6LfR7ca0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Music Is Our Drug',
#     'tags': ['Gramatik',
#      'Torture',
#      'The Age Of Reason',
#      '2014',
#      'Music Is Our Drug',
#      'guitar',
#      'Eric Krisno'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Gramatik - Torture (feat. Eric Krasno)',
#      'description': '♫ Music Is Our Drug - Spotify Playlist: https://goo.gl/rJvM5l\n►Follow us on Spotify: https://goo.gl/HqOgkN\n\nTorture from the new Gramatik album - The Age Of Reason!\nGramatik:\nhttps://soundcloud.com/gramatik\nhttps://www.facebook.com/gramatik\n\nImage:\nhttp://www.allwalls.net/wallpapers/2012/09/Women-Graffiti-Stadium-Bracelets-1800x2880.jpg\n\n(If any producer or label has an issue with any of the uploads please get in contact with me on YouTube and I will delete it as soon as possible (this includes artists of the images used).'}},
#    'contentDetails': {'duration': 'PT3M43S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '29187',
#     'likeCount': '255',
#     'dislikeCount': '0',
#     'favoriteCount': '0',
#     'commentCount': '5'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '4KKAD3q8wsBr-OJqkBuPYGbLAA4',
#    'id': 'DaH4W1rY9us',
#    'snippet': {'publishedAt': '2012-12-02T12:41:13Z',
#     'channelId': 'UCJsTMPZxYD-Q3kEmL4Qijpg',
#     'title': 'Ben Howard - Oats In The Water',
#     'description': 'Buy The Burgh Island EP now:\nhttps://itunes.apple.com/gb/album/burgh-island-ep/id571218980?affId=1657369&ign-mpt=uo%3D4 \n\nNO COPYRIGHT INFRINGEMENT INTENDED',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DaH4W1rY9us/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DaH4W1rY9us/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DaH4W1rY9us/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/DaH4W1rY9us/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/DaH4W1rY9us/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Harvey Pearson',
#     'tags': ['Ben Howard',
#      'Oats In The Water',
#      'Music Video',
#      'BBC Radio One',
#      'Zane Lowe',
#      'Greg James',
#      'Mickey Smith',
#      'Wales',
#      'Surf',
#      'Black And White',
#      'The Burgh Island EP',
#      'Burgh Island',
#      'Ireland',
#      'Astray Films',
#      'Harvey Pearson',
#      'Hounddogpictures',
#      'hdp',
#      'productions',
#      'iTunes',
#      'sony',
#      'nex',
#      '5n',
#      'Timelapse',
#      'CS6',
#      'Ben',
#      'Howard',
#      '(musician)',
#      'old',
#      'pine',
#      'only',
#      'love',
#      'keep',
#      'your',
#      'head',
#      'up',
#      'every',
#      'kingdom',
#      'harvpearson',
#      'official',
#      'video',
#      'music',
#      'Devon',
#      'beach',
#      'surf',
#      'surfers',
#      'Waves',
#      'Ocean',
#      'Hound Dog Pictures Productions',
#      'Sand',
#      'Surfing'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Ben Howard - Oats In The Water',
#      'description': 'Buy The Burgh Island EP now:\nhttps://itunes.apple.com/gb/album/burgh-island-ep/id571218980?affId=1657369&ign-mpt=uo%3D4 \n\nNO COPYRIGHT INFRINGEMENT INTENDED'}},
#    'contentDetails': {'duration': 'PT5M',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '16706477',
#     'likeCount': '138594',
#     'dislikeCount': '1814',
#     'favoriteCount': '0',
#     'commentCount': '5366'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/064t9',
#      '/m/05rwpb',
#      '/m/04rlf',
#      '/m/064t9',
#      '/m/05rwpb'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Pop_music',
#      'https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'ADat4868rhUoxV-B_pN417RZGdE',
#    'id': 'PAAUqBghiVo',
#    'snippet': {'publishedAt': '2013-10-15T09:30:25Z',
#     'channelId': 'UCDHvlud7Hf86FxFsogrBcMg',
#     'title': 'RA Sessions: DARKSIDE - Paper Trails',
#     'description': 'Subscribe to the RA YouTube channel: http://bit.ly/1x7PeGy\n\nVisit the feature page: http://www.residentadvisor.net/feature.aspx?1959\n\nLast week Nicolas Jaar and Dave Harrington released Psychic, their debut album as Darkside. "Darkside is utterly sincere," said Tony Naylor in his RA review, "and at its most fractured and psychedelic, Harrington\'s guitar lends a smoky, mysterious dimension to Jaar\'s slinky electronica." "Paper Trails" is the record\'s dazzling midpoint, and in the first RA Sessions film, recorded at RA\'s HQ, Jaar and Harrington sank a couple of whiskeys and subtly teased the track out to twice its original length.\n\n\nCredits:\nProducer & Director - Patrick Nation\nCamera - Patrick Nation, Luke Ogden\nSound Engineers - Vance Galloway, Rich Cufley (Sound Services)\nProduction Assistant - Debbie Butts',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PAAUqBghiVo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PAAUqBghiVo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PAAUqBghiVo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PAAUqBghiVo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PAAUqBghiVo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Resident Advisor',
#     'tags': ['Resident Advisor (Website)',
#      'RA',
#      'darkside',
#      'psychic',
#      'paper trails',
#      'Nicolas Jaar (Musical Artist)',
#      'dave harrington',
#      'session',
#      'live session',
#      'live music',
#      'electronic music',
#      'Live',
#      'EDM',
#      'guitar',
#      'Wurlitzer Electric Piano (Product Line)',
#      'wurlitzer',
#      'Performance (Project)',
#      'Hardware',
#      'Liveset',
#      'Analog',
#      'Resident Advisor',
#      'Nico Jaar',
#      'Nicolas Jaar',
#      'Nicholas',
#      'Jaar',
#      'Performance',
#      'Paper Trail',
#      'DJ',
#      'Music'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'RA Sessions: DARKSIDE - Paper Trails',
#      'description': 'Subscribe to the RA YouTube channel: http://bit.ly/1x7PeGy\n\nVisit the feature page: http://www.residentadvisor.net/feature.aspx?1959\n\nLast week Nicolas Jaar and Dave Harrington released Psychic, their debut album as Darkside. "Darkside is utterly sincere," said Tony Naylor in his RA review, "and at its most fractured and psychedelic, Harrington\'s guitar lends a smoky, mysterious dimension to Jaar\'s slinky electronica." "Paper Trails" is the record\'s dazzling midpoint, and in the first RA Sessions film, recorded at RA\'s HQ, Jaar and Harrington sank a couple of whiskeys and subtly teased the track out to twice its original length.\n\n\nCredits:\nProducer & Director - Patrick Nation\nCamera - Patrick Nation, Luke Ogden\nSound Engineers - Vance Galloway, Rich Cufley (Sound Services)\nProduction Assistant - Debbie Butts'}},
#    'contentDetails': {'duration': 'PT10M16S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '3438413',
#     'likeCount': '38046',
#     'dislikeCount': '455',
#     'favoriteCount': '0',
#     'commentCount': '894'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/02lkt',
#      '/m/02lkt',
#      '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Electronic_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'qFK-HoYTQWSK8ChibfTukC2E7VI',
#    'id': '7CkBU80AsVg',
#    'snippet': {'publishedAt': '2010-12-18T19:19:36Z',
#     'channelId': 'UCr7vKEGOLRCf4ivVzUcK6dw',
#     'title': 'Dusty Kid - America',
#     'description': "Dusty Kid's America.\r\n\r\nDirected by @mattcastilho\r\nwww.mattcastilho.com",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7CkBU80AsVg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7CkBU80AsVg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7CkBU80AsVg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Matheus Castilho',
#     'tags': ['dusty kid america',
#      'tiesto',
#      'armin',
#      'van',
#      'buuren',
#      'animals',
#      'the',
#      'underground',
#      'progressive',
#      'elctro',
#      'house',
#      'electronic',
#      'music',
#      'paul',
#      'dyk',
#      'adam',
#      'deadmau5'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Dusty Kid - America',
#      'description': "Dusty Kid's America.\r\n\r\nDirected by @mattcastilho\r\nwww.mattcastilho.com"}},
#    'contentDetails': {'duration': 'PT7M59S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '29637',
#     'likeCount': '182',
#     'dislikeCount': '6',
#     'favoriteCount': '0',
#     'commentCount': '10'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/02lkt',
#      '/m/04rlf',
#      '/m/02lkt'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Electronic_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'YeYHps_x7hIYcS4VQPi3Lv5owUc',
#    'id': 'lddHsCBdQu8',
#    'snippet': {'publishedAt': '2013-05-15T08:19:20Z',
#     'channelId': 'UCX_fIhJAag_NvUN7I1dwjBg',
#     'title': 'MØ - Waste Of Time (Official Audio)',
#     'description': "Official Audio | MØ - Waste of Time\n\n\nSubscribe to the MØ YouTube Channel:  http://smarturl.it/MOytb\n\n\n'No Mythologies To Follow' is out now!\n\niTunes: http://smarturl.it/MO_NMTF_digi \nAmazon: http://smarturl.it/MO_NMTF_AMZ \nOfficial Store: http://smarturl.it/MOstore \nVinyl: http://smarturl.it/MO_NMTF_RT \n\nSign up to my official mailing list http://smarturl.it/MOmail \n\nFollow me here:\nhttp://open.spotify.com/artist/0bdfiayQAKewqEvaU6rXCv \nhttp://www.facebook.com/MOMOMOYOUTH \nhttp://twitter.com/MOMOMOYOUTH \nhttp://www.momomoyouth.com/ \nhttp://www.youtube.com/user/MOMOMOYOUTH\n\n#MØ\n#WasteOfTime",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lddHsCBdQu8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lddHsCBdQu8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lddHsCBdQu8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lddHsCBdQu8/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'MOMOMOYOUTH',
#     'tags': ['MØ',
#      'momomoyouth',
#      'mo',
#      'mø',
#      'mø waste of time',
#      'waste of time',
#      'moe',
#      'mo waste of time'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'MØ - Waste Of Time (Official Audio)',
#      'description': "Official Audio | MØ - Waste of Time\n\n\nSubscribe to the MØ YouTube Channel:  http://smarturl.it/MOytb\n\n\n'No Mythologies To Follow' is out now!\n\niTunes: http://smarturl.it/MO_NMTF_digi \nAmazon: http://smarturl.it/MO_NMTF_AMZ \nOfficial Store: http://smarturl.it/MOstore \nVinyl: http://smarturl.it/MO_NMTF_RT \n\nSign up to my official mailing list http://smarturl.it/MOmail \n\nFollow me here:\nhttp://open.spotify.com/artist/0bdfiayQAKewqEvaU6rXCv \nhttp://www.facebook.com/MOMOMOYOUTH \nhttp://twitter.com/MOMOMOYOUTH \nhttp://www.momomoyouth.com/ \nhttp://www.youtube.com/user/MOMOMOYOUTH\n\n#MØ\n#WasteOfTime"}},
#    'contentDetails': {'duration': 'PT3M34S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '752125',
#     'likeCount': '6623',
#     'dislikeCount': '96',
#     'favoriteCount': '0',
#     'commentCount': '261'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/064t9',
#      '/m/04rlf',
#      '/m/064t9'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Pop_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'bjZptmkytseep2wuQAAhFKwKOp8',
#    'id': 'mhsf7K6h7SY',
#    'snippet': {'publishedAt': '2014-01-15T18:33:15Z',
#     'channelId': 'UCJ6td3C9QlPO9O_J5dF4ZzA',
#     'title': '[Electronic] - Pegboard Nerds - Bassline Kickin [Monstercat Release]',
#     'description': "Nerds by Nature 2016 Spring Tour on Sale NOW at http://www.PegboardNerds.com\n---\n▼ This song is featured on Monstercat 016 - Expedition. \nGet all 30 tracks plus 2 album mixes by downloading it here:\n\nSupport on iTunes: http://monster.cat/1fsmpQy\nSupport on Bandcamp: http://monster.cat/1hpp7oo\nSupport on Amazon: http://monster.cat/1dAiMCc\nSupport on Google Play: http://monster.cat/1dAm7RR\nListen on Spotify: http://monster.cat/1hzwp7R\n----\nArrival Album Mix: http://monster.cat/1hqcv0b\n\nTo support the single only:\n\nPlease consider supporting on Beatport: http://monster.cat/BasslineKickin\nListen on SoundCloud: \nhttp://monster.cat/1hrfghr\n\nWe're looking to make an impact with this release and show that it is possible to have something different top the charts. Your Beatport purchase will help make the difference.\n\n▼ Follow Monstercat\nSnapchat: Monstercat\nYouTube: http://www.youtube.com/Monstercat\nSpotify: http://monster.cat/1hGrCWk\nFacebook: http://facebook.com/Monstercat\nTwitter: http://twitter.com/Monstercat\nInstagram: http://instagram.com/monstercat\nSoundCloud: http://soundcloud.com/Monstercat\nGoogle+: https://plus.google.com/+Monstercat\n\n▼ Follow Pegboard Nerds\nFacebook: http://facebook.com/PegboardNerds\nTwitter: http://twitter.com/PegboardNerds\nSoundCloud: http://soundcloud.com/pegboardnerds\nYouTube: http://youtube.com/PegboardNerds\n\n▼ Want some new Merchandise?\nhttp://monster.cat/MonstercatShop\n\nMonstercat 017 - Ascension is now available! Support your favourite rising Monstercat artists with a purchase here: http://www.monstercat.com/ascension/ /\n-----------------------------------\nWant to use this song in your own videos? Please go to: http://monster.cat/YouTube_License",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mhsf7K6h7SY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mhsf7K6h7SY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mhsf7K6h7SY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/mhsf7K6h7SY/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Monstercat: Uncaged',
#     'tags': ['Pegboard',
#      'Nerds',
#      'Bassline',
#      'Kickin',
#      'Electronic',
#      'Dance',
#      'Monstercat',
#      'EDM',
#      'Grey',
#      'Best Electronic',
#      'New Electronic',
#      'Top Electronic',
#      'Electronic 2013',
#      'Best EDM',
#      'New EDM',
#      'Top EDM',
#      'EDM 2013',
#      'Peg Board',
#      'Nerdz'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '[Electronic] - Pegboard Nerds - Bassline Kickin [Monstercat Release]',
#      'description': "Nerds by Nature 2016 Spring Tour on Sale NOW at http://www.PegboardNerds.com\n---\n▼ This song is featured on Monstercat 016 - Expedition. \nGet all 30 tracks plus 2 album mixes by downloading it here:\n\nSupport on iTunes: http://monster.cat/1fsmpQy\nSupport on Bandcamp: http://monster.cat/1hpp7oo\nSupport on Amazon: http://monster.cat/1dAiMCc\nSupport on Google Play: http://monster.cat/1dAm7RR\nListen on Spotify: http://monster.cat/1hzwp7R\n----\nArrival Album Mix: http://monster.cat/1hqcv0b\n\nTo support the single only:\n\nPlease consider supporting on Beatport: http://monster.cat/BasslineKickin\nListen on SoundCloud: \nhttp://monster.cat/1hrfghr\n\nWe're looking to make an impact with this release and show that it is possible to have something different top the charts. Your Beatport purchase will help make the difference.\n\n▼ Follow Monstercat\nSnapchat: Monstercat\nYouTube: http://www.youtube.com/Monstercat\nSpotify: http://monster.cat/1hGrCWk\nFacebook: http://facebook.com/Monstercat\nTwitter: http://twitter.com/Monstercat\nInstagram: http://instagram.com/monstercat\nSoundCloud: http://soundcloud.com/Monstercat\nGoogle+: https://plus.google.com/+Monstercat\n\n▼ Follow Pegboard Nerds\nFacebook: http://facebook.com/PegboardNerds\nTwitter: http://twitter.com/PegboardNerds\nSoundCloud: http://soundcloud.com/pegboardnerds\nYouTube: http://youtube.com/PegboardNerds\n\n▼ Want some new Merchandise?\nhttp://monster.cat/MonstercatShop\n\nMonstercat 017 - Ascension is now available! Support your favourite rising Monstercat artists with a purchase here: http://www.monstercat.com/ascension/ /\n-----------------------------------\nWant to use this song in your own videos? Please go to: http://monster.cat/YouTube_License"}},
#    'contentDetails': {'duration': 'PT3M58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '1725401',
#     'likeCount': '22713',
#     'dislikeCount': '780',
#     'favoriteCount': '0',
#     'commentCount': '2507'}},
#   {'kind': 'youtube#video',
#    'etag': 'ZJw9tRxa9gJS1NoBxX_be5DndNY',
#    'id': '3go6xFb0FrU',
#    'snippet': {'publishedAt': '2009-10-01T20:53:09Z',
#     'channelId': 'UCPoG8-NKfLQ23kmWX2XKDwQ',
#     'title': 'Always Coca Cola A cappella',
#     'description': 'Triple tribute to:\r\n\r\n-Rockapella: the great a capella band. http://www.rockapella.com/\r\n\r\n-Corey Vidal: That dude really rocks !!\r\nhttp://www.youtube.com/user/ApprenticeA\r\n\r\n-Coca-cola: well you know that.\r\nhttp://www.coca-cola.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3go6xFb0FrU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3go6xFb0FrU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3go6xFb0FrU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'WassupTeam',
#     'tags': ['coca',
#      'cola',
#      'coca-cola',
#      'song',
#      'cappella',
#      'rockappella',
#      'capella',
#      'rockapella',
#      'lip',
#      'sync',
#      'tribute',
#      'corey',
#      'vidal'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Always Coca Cola A cappella',
#      'description': 'Triple tribute to:\r\n\r\n-Rockapella: the great a capella band. http://www.rockapella.com/\r\n\r\n-Corey Vidal: That dude really rocks !!\r\nhttp://www.youtube.com/user/ApprenticeA\r\n\r\n-Coca-cola: well you know that.\r\nhttp://www.coca-cola.com'}},
#    'contentDetails': {'duration': 'PT1M7S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '30559',
#     'likeCount': '187',
#     'dislikeCount': '11',
#     'favoriteCount': '0',
#     'commentCount': '18'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '4SPNMj8BiHN_3Npk-SPNbau30mU',
#    'id': 'L4OZxO1TnuE',
#    'snippet': {'publishedAt': '2013-05-27T08:42:35Z',
#     'channelId': 'UCdq-B0LX11PFyGRVQ9nn9tA',
#     'title': 'Dom La Nena  03 Vento',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L4OZxO1TnuE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L4OZxO1TnuE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L4OZxO1TnuE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L4OZxO1TnuE/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Joana F.',
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Dom La Nena  03 Vento', 'description': ''}},
#    'contentDetails': {'duration': 'PT3M21S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '9242',
#     'likeCount': '63',
#     'dislikeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '1'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'wdvQBik5PHqTp9Ib1uS6dAMz4R8',
#    'id': 'AWmjDPfGIPs',
#    'snippet': {'publishedAt': '2012-05-02T18:05:17Z',
#     'channelId': 'UC2GK1jS6xrYTh4Xo9qsYSgQ',
#     'title': 'Lazare Hoche - Luv Thang (LH Edits Limited Sampler)',
#     'description': 'Lazare Hoche - Luv Thang : Label - LH Edits : Released - 7th May 2012 : http://www.juno.co.uk/ppps/products/454244-01.htm',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AWmjDPfGIPs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AWmjDPfGIPs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AWmjDPfGIPs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AWmjDPfGIPs/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Gazzz696',
#     'tags': ['disco', 'edits'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Lazare Hoche - Luv Thang (LH Edits Limited Sampler)',
#      'description': 'Lazare Hoche - Luv Thang : Label - LH Edits : Released - 7th May 2012 : http://www.juno.co.uk/ppps/products/454244-01.htm'}},
#    'contentDetails': {'duration': 'PT5M28S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '93164',
#     'likeCount': '1151',
#     'dislikeCount': '18',
#     'favoriteCount': '0',
#     'commentCount': '13'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '5M9Rtu7SOECMT4RU6jAYd5X9Upk',
#    'id': 'licyt5FQ0cU',
#    'snippet': {'publishedAt': '2009-10-02T03:14:44Z',
#     'channelId': 'UCTvdoLDE9nGiJ4Y_Mjn4Nrw',
#     'title': 'Liars - The Other Side of Mt. Heart Attack',
#     'description': "A quickly made video for 'The Other Side of Mt. Heart Attack' by Liars from the record 'Drums Not Dead.' First attempt at a video.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/licyt5FQ0cU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/licyt5FQ0cU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/licyt5FQ0cU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'zpobric',
#     'tags': ['Liars', 'Mt. Heart Attack', 'Drums Not Dead', 'Mountain'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Liars - The Other Side of Mt. Heart Attack',
#      'description': "A quickly made video for 'The Other Side of Mt. Heart Attack' by Liars from the record 'Drums Not Dead.' First attempt at a video."}},
#    'contentDetails': {'duration': 'PT4M44S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '181523',
#     'likeCount': '1588',
#     'dislikeCount': '33',
#     'favoriteCount': '0',
#     'commentCount': '90'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/06by7',
#      '/m/05rwpb',
#      '/m/064t9',
#      '/m/04rlf',
#      '/m/06by7',
#      '/m/064t9'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Pop_music',
#      'https://en.wikipedia.org/wiki/Rock_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'u2VUw9s2INXKvf0UwdZbw9Xahjw',
#    'id': '88tsEjceu78',
#    'snippet': {'publishedAt': '2006-01-13T09:54:37Z',
#     'channelId': 'UCmMstRn9yTFPjwAi20ImULA',
#     'title': "NTM - That's my people",
#     'description': 'video',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/88tsEjceu78/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/88tsEjceu78/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/88tsEjceu78/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mony1',
#     'tags': ['ntm', 'video'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': "NTM - That's my people", 'description': 'video'}},
#    'contentDetails': {'duration': 'PT4M12S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'regionRestriction': {'blocked': ['CF',
#       'CG',
#       'CD',
#       'CC',
#       'CA',
#       'CN',
#       'CO',
#       'CL',
#       'CM',
#       'VE',
#       'CK',
#       'CH',
#       'CI',
#       'CV',
#       'CW',
#       'CU',
#       'CR',
#       'CZ',
#       'CX',
#       'CY',
#       'NA',
#       'NC',
#       'NE',
#       'NG',
#       'NF',
#       'NI',
#       'VN',
#       'NL',
#       'NO',
#       'NP',
#       'TW',
#       'NR',
#       'NU',
#       'NZ',
#       'VC',
#       'SV',
#       'DZ',
#       'DO',
#       'DM',
#       'DK',
#       'DJ',
#       'DE',
#       'KN',
#       'ST',
#       'KM',
#       'SR',
#       'SS',
#       'KH',
#       'KI',
#       'KG',
#       'KE',
#       'SZ',
#       'SX',
#       'SY',
#       'SG',
#       'SD',
#       'SE',
#       'KZ',
#       'SC',
#       'KY',
#       'SN',
#       'KW',
#       'SL',
#       'SM',
#       'KR',
#       'SK',
#       'KP',
#       'SI',
#       'EC',
#       'EE',
#       'EG',
#       'EH',
#       'VG',
#       'ER',
#       'ES',
#       'ET',
#       'PY',
#       'IO',
#       'PS',
#       'PR',
#       'PW',
#       'PT',
#       'PK',
#       'PH',
#       'PN',
#       'PM',
#       'PL',
#       'SB',
#       'PA',
#       'PG',
#       'PF',
#       'PE',
#       'RU',
#       'BN',
#       'FR',
#       'RW',
#       'FI',
#       'FK',
#       'FJ',
#       'FM',
#       'FO',
#       'SO',
#       'MH',
#       'MK',
#       'ML',
#       'MM',
#       'VI',
#       'MO',
#       'TJ',
#       'MA',
#       'UZ',
#       'MC',
#       'MD',
#       'ME',
#       'VU',
#       'MG',
#       'MX',
#       'MY',
#       'MZ',
#       'SH',
#       'UG',
#       'MP',
#       'MQ',
#       'MR',
#       'MS',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'TO',
#       'GY',
#       'TN',
#       'GR',
#       'GS',
#       'ZW',
#       'GQ',
#       'GW',
#       'GT',
#       'GU',
#       'ZM',
#       'GH',
#       'GI',
#       'GN',
#       'GL',
#       'GM',
#       'GB',
#       'GA',
#       'ZA',
#       'GG',
#       'GD',
#       'GE',
#       'JM',
#       'MF',
#       'JO',
#       'RS',
#       'JE',
#       'TH',
#       'IQ',
#       'RE',
#       'TG',
#       'VA',
#       'TF',
#       'RO',
#       'JP',
#       'TV',
#       'HR',
#       'TD',
#       'HU',
#       'HT',
#       'WF',
#       'US',
#       'HK',
#       'WS',
#       'HN',
#       'HM',
#       'SJ',
#       'MN',
#       'OM',
#       'UY',
#       'IT',
#       'AM',
#       'TM',
#       'TL',
#       'TK',
#       'AI',
#       'IR',
#       'IS',
#       'AD',
#       'AE',
#       'AF',
#       'AG',
#       'TC',
#       'ID',
#       'IE',
#       'AX',
#       'TZ',
#       'AZ',
#       'IM',
#       'IL',
#       'AU',
#       'IN',
#       'TT',
#       'AQ',
#       'AR',
#       'AS',
#       'AL',
#       'AW',
#       'LC',
#       'LB',
#       'LA',
#       'UA',
#       'GP',
#       'LK',
#       'LI',
#       'TR',
#       'BO',
#       'LV',
#       'LU',
#       'LT',
#       'LS',
#       'LR',
#       'LY',
#       'BE',
#       'YE',
#       'BG',
#       'BF',
#       'BA',
#       'GF',
#       'BB',
#       'BM',
#       'BL',
#       'BD',
#       'AT',
#       'BI',
#       'BH',
#       'BJ',
#       'YT',
#       'BT',
#       'BW',
#       'BV',
#       'BQ',
#       'BS',
#       'BR',
#       'BY',
#       'BZ',
#       'UM',
#       'AO',
#       'QA',
#       'SA']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '4762998',
#     'likeCount': '12196',
#     'dislikeCount': '264',
#     'favoriteCount': '0',
#     'commentCount': '1699'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/0glt670',
#      '/m/04rlf',
#      '/m/0glt670'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Hip_hop_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'BH1nhVKCsU_A90UvCqdn9ih4brE',
#    'id': 'hPyzYcrVU-k',
#    'snippet': {'publishedAt': '2006-10-14T05:33:19Z',
#     'channelId': 'UC5waXguxTDV09TNHkjhHAuQ',
#     'title': 'La maman et la putain, Diabologum',
#     'description': 'Footage is from Jean Eustache\'s cult movie "La maman et la putain". My favorite movie, so it was the best Avid Xpress training project! \n\nFilm ecrit et realise par Jean Eustache (1973). La musique est de Diabologum, sur leur album "#3" (1996).\n\nRéduire un tel film de 3h40 à 6 minutes est probablement un crime, mais je m\'estime pardonné si le clip encourage 6 personnes à découvrir l\'oeuvre d\'Eustache! Montage réalisé sous Avid Xpress Pro, à partir d\'une version DivX du film (n\'étant pas disponible en DVD). [juin 2004]',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hPyzYcrVU-k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hPyzYcrVU-k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hPyzYcrVU-k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mudar Noufal',
#     'tags': ['Jean',
#      'Eustache',
#      'Diabologum',
#      'La',
#      'maman',
#      'et',
#      'la',
#      'putain',
#      'Françoise',
#      'Lebrun',
#      'Jean-Pierre',
#      'Léaud'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'La maman et la putain, Diabologum',
#      'description': 'Footage is from Jean Eustache\'s cult movie "La maman et la putain". My favorite movie, so it was the best Avid Xpress training project! \n\nFilm ecrit et realise par Jean Eustache (1973). La musique est de Diabologum, sur leur album "#3" (1996).\n\nRéduire un tel film de 3h40 à 6 minutes est probablement un crime, mais je m\'estime pardonné si le clip encourage 6 personnes à découvrir l\'oeuvre d\'Eustache! Montage réalisé sous Avid Xpress Pro, à partir d\'une version DivX du film (n\'étant pas disponible en DVD). [juin 2004]'},
#     'defaultAudioLanguage': 'fr-FR'},
#    'contentDetails': {'duration': 'PT6M2S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '212907',
#     'likeCount': '370',
#     'dislikeCount': '19',
#     'favoriteCount': '0',
#     'commentCount': '24'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/05rwpb',
#      '/m/04rlf',
#      '/m/05rwpb'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'B144xa_U7kLzqcDu1VcZvL_sP98',
#    'id': '6gwbXjHNcwA',
#    'snippet': {'publishedAt': '2007-12-12T00:34:15Z',
#     'channelId': 'UCrkwXyJhnXPBAtG7sxSk2Gw',
#     'title': 'The Strokes - Automatic Stop',
#     'description': 'from Room on Fire',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6gwbXjHNcwA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6gwbXjHNcwA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6gwbXjHNcwA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'pcindarellie',
#     'tags': ['The', 'Strokes', 'Automatic', 'Stop'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'The Strokes - Automatic Stop',
#      'description': 'from Room on Fire'}},
#    'contentDetails': {'duration': 'PT3M28S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '3117121',
#     'likeCount': '13496',
#     'dislikeCount': '284',
#     'favoriteCount': '0'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/06by7',
#      '/m/06by7',
#      '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Rock_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '1KmirrSQr1MswZTsQc9NM59sBT8',
#    'id': 'jNlDkOkYY30',
#    'snippet': {'publishedAt': '2013-08-30T14:01:24Z',
#     'channelId': 'UC6AHeJa7s9-Brs6VyXy6Dwg',
#     'title': 'Skyden feat. Saska - Burning Light (Official Video)',
# ...
#     'likeCount': '6133',
#     'dislikeCount': '119',
#     'favoriteCount': '0',
#     'commentCount': '231'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/05rwpb',
#      '/m/04rlf',
#      '/m/05rwpb'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'XqcQpFzN5fZGuZuwTfcaEB_Rgyo',
#    'id': 'BERilmKPRAQ',
#    'snippet': {'publishedAt': '2012-06-07T15:58:26Z',
#     'channelId': 'UCngnwyUpm1TJwPs1KgA8hMA',
#     'title': 'Blackmail - A Miracle America | HQ',
#     'description': 'http://soundcloud.com/blackmail-1',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BERilmKPRAQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BERilmKPRAQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BERilmKPRAQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BERilmKPRAQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BERilmKPRAQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Eliana Teixeira',
#     'tags': ['france',
#      'america',
#      'miracle',
#      "she's crafty",
#      'blackmail',
#      'a miracle america',
#      'electronic',
#      'dark',
#      'hipster',
#      'SYNTH',
#      'ROCK'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Blackmail - A Miracle America | HQ',
#      'description': 'http://soundcloud.com/blackmail-1'}},
#    'contentDetails': {'duration': 'PT5M17S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '4863',
#     'likeCount': '32',
#     'dislikeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '1'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/06by7',
#      '/m/02lkt',
#      '/m/04rlf',
#      '/m/06by7',
#      '/m/02lkt'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Electronic_music',
#      'https://en.wikipedia.org/wiki/Rock_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': '_BSB0-cFUM_QmANBP6GqeOdpjbM',
#    'id': 'CjwwmFrsX_E',
#    'snippet': {'publishedAt': '2014-02-13T21:19:39Z',
#     'channelId': 'UCd2KNtfphz8HvYzM4pwtHmg',
#     'title': "CHVRCHES cover Arctic Monkeys 'Do I Wanna Know?' for Like A Version",
#     'description': "Scottish electrio CHVRCHES cover Arctic Monkeys 'Do I Wanna Know?' for triple j's Like A Version. \nSubscribe | http://bit.ly/2FYj5jC\nLike A Version on Spotify | https://spoti.fi/2UpMDcU \nLike A Version on Apple Music | https://apple.co/2NMJ7Y4\nFacebook | http://bit.ly/iJ0OH9 \nInstagram | http://bit.ly/2CWGnCA  \nTwitter | http://bit.ly/2BdFOUI\n\nLike A Version is a segment on Australian radio station triple j. Every week a musician or band comes into the studio to play one of their own songs and cover a song they love. \n\nSince 2004, many artists have participated, including Childish Gambino, Lorde, CHVRCHES, Tame Impala, Tash Sultana, HAIM, Gang of Youths, Halsey, DMA'S, Aurora, Arctic Monkeys. You can watch past sessions here: http://bit.ly/like_a_version\n\nYou can watch Like A Versions ad-free at http://www.triplej.net.au\n\n#LikeAVersion",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CjwwmFrsX_E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CjwwmFrsX_E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CjwwmFrsX_E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/CjwwmFrsX_E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/CjwwmFrsX_E/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'triple j',
#     'tags': ['Chvrches',
#      'Arctic Monkeys',
#      'Like A Version',
#      'triple j',
#      'Do I Wanna Know?',
#      'Lauren Mayberry',
#      'Laneway Festival',
#      'like a version',
#      'cover',
#      'live',
#      'triplej',
#      'jjj',
#      'matt and alex',
#      'matt & alex',
#      'matt okine',
#      'alex dyson',
#      'breakfast show',
#      'breakfast radio',
#      'radio',
#      'breakfast',
#      'music',
#      'Australian Music',
#      'Australian',
#      'Australia',
#      'studio',
#      'abc'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': "CHVRCHES cover Arctic Monkeys 'Do I Wanna Know?' for Like A Version",
#      'description': "Scottish electrio CHVRCHES cover Arctic Monkeys 'Do I Wanna Know?' for triple j's Like A Version. \nSubscribe | http://bit.ly/2FYj5jC\nLike A Version on Spotify | https://spoti.fi/2UpMDcU \nLike A Version on Apple Music | https://apple.co/2NMJ7Y4\nFacebook | http://bit.ly/iJ0OH9 \nInstagram | http://bit.ly/2CWGnCA  \nTwitter | http://bit.ly/2BdFOUI\n\nLike A Version is a segment on Australian radio station triple j. Every week a musician or band comes into the studio to play one of their own songs and cover a song they love. \n\nSince 2004, many artists have participated, including Childish Gambino, Lorde, CHVRCHES, Tame Impala, Tash Sultana, HAIM, Gang of Youths, Halsey, DMA'S, Aurora, Arctic Monkeys. You can watch past sessions here: http://bit.ly/like_a_version\n\nYou can watch Like A Versions ad-free at http://www.triplej.net.au\n\n#LikeAVersion"}},
#    'contentDetails': {'duration': 'PT5M14S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '12579117',
#     'likeCount': '105210',
#     'dislikeCount': '6605',
#     'favoriteCount': '0',
#     'commentCount': '4503'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/05rwpb',
#      '/m/04rlf',
#      '/m/05rwpb'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'KJAEk4OmO37IorbqgzrV2yA0mMI',
#    'id': 'kPvLT-Wa5Rs',
#    'snippet': {'publishedAt': '2012-08-21T04:00:10Z',
#     'channelId': 'UCJisrqMX102yOunQkQXVR4w',
#     'title': 'Liam Bailey - Please Love Me',
#     'description': "Liam Bailey - Please Love Me \n \nLiam Bailey's new single 'Please Love Me' is out now on Truth and Soul Records. \n \nDownload on iTunes: http://t.co/ogiXWtIJ \nOrder the single on vinyl: http://truthandsoulrecords.com/artists/liam-bailey-2/\n \n'Like' Liam Bailey on Facebook: https://www.facebook.com/liambaileymusic\nFollow Liam Bailey on Twitter: http://twitter.com/liambailey\nSubscribe to Liam Bailey's channel here: http://www.youtube.com/subscription_center?gl=CA&add_user=liambaileymusic",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kPvLT-Wa5Rs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kPvLT-Wa5Rs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kPvLT-Wa5Rs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kPvLT-Wa5Rs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kPvLT-Wa5Rs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'LiamBaileyVEVO',
#     'tags': ['truth',
#      'soul',
#      'liam',
#      'bailey',
#      'funk',
#      'lee',
#      'fields',
#      'el',
#      'michels',
#      'affair',
#      'brooklyn',
#      "'liam bailey'",
#      'bayley',
#      "'chase & status'",
#      'blind faith',
#      "'it's not the same'",
#      'better leave me',
#      'nottingham',
#      'london',
#      "'when will they learn'",
#      'dub',
#      'skank',
#      'mistajam',
#      'acoustic',
#      "'michael kiwanuka'",
#      'delilah',
#      'new'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Liam Bailey - Please Love Me',
#      'description': "Liam Bailey - Please Love Me \n \nLiam Bailey's new single 'Please Love Me' is out now on Truth and Soul Records. \n \nDownload on iTunes: http://t.co/ogiXWtIJ \nOrder the single on vinyl: http://truthandsoulrecords.com/artists/liam-bailey-2/\n \n'Like' Liam Bailey on Facebook: https://www.facebook.com/liambaileymusic\nFollow Liam Bailey on Twitter: http://twitter.com/liambailey\nSubscribe to Liam Bailey's channel here: http://www.youtube.com/subscription_center?gl=CA&add_user=liambaileymusic"}},
#    'contentDetails': {'duration': 'PT2M55S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'blocked': ['CF',
#       'CG',
#       'CD',
#       'CC',
#       'CA',
#       'CN',
#       'CO',
#       'CL',
#       'CM',
#       'VE',
#       'CK',
#       'CH',
#       'CI',
#       'CV',
#       'CW',
#       'CU',
#       'CR',
#       'ZW',
#       'CZ',
#       'CX',
#       'CY',
#       'NA',
#       'NC',
#       'NE',
#       'NG',
#       'NF',
#       'NI',
#       'VN',
#       'NL',
#       'NO',
#       'VA',
#       'TW',
#       'NR',
#       'NU',
#       'ZA',
#       'YE',
#       'NZ',
#       'VC',
#       'KN',
#       'DZ',
#       'DO',
#       'DM',
#       'DK',
#       'DJ',
#       'DE',
#       'SV',
#       'ST',
#       'KM',
#       'SR',
#       'SS',
#       'KH',
#       'KI',
#       'KG',
#       'KE',
#       'SZ',
#       'SX',
#       'SY',
#       'SG',
#       'SD',
#       'SE',
#       'KZ',
#       'SC',
#       'KY',
#       'SN',
#       'KW',
#       'SL',
#       'SM',
#       'KR',
#       'SK',
#       'KP',
#       'SI',
#       'EC',
#       'EE',
#       'VI',
#       'EG',
#       'IQ',
#       'VG',
#       'ER',
#       'ES',
#       'ET',
#       'PY',
#       'TO',
#       'PS',
#       'PR',
#       'PW',
#       'PT',
#       'PK',
#       'PH',
#       'PN',
#       'PM',
#       'PL',
#       'SB',
#       'PA',
#       'PG',
#       'PF',
#       'PE',
#       'RU',
#       'IL',
#       'FR',
#       'RW',
#       'FI',
#       'FK',
#       'FJ',
#       'FM',
#       'FO',
#       'SO',
#       'EH',
#       'VU',
#       'MH',
#       'US',
#       'ML',
#       'MM',
#       'MN',
#       'MO',
#       'TJ',
#       'MA',
#       'UZ',
#       'MC',
#       'MD',
#       'ME',
#       'MF',
#       'MG',
#       'MX',
#       'MY',
#       'MZ',
#       'SH',
#       'UG',
#       'MP',
#       'MQ',
#       'MR',
#       'MS',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'IT',
#       'GY',
#       'TN',
#       'GR',
#       'GS',
#       'GP',
#       'GQ',
#       'GW',
#       'GT',
#       'GU',
#       'ZM',
#       'GH',
#       'GI',
#       'GN',
#       'GL',
#       'GM',
#       'GB',
#       'GA',
#       'GF',
#       'GG',
#       'GD',
#       'GE',
#       'JM',
#       'JO',
#       'RS',
#       'NP',
#       'JE',
#       'TH',
#       'RE',
#       'TG',
#       'AE',
#       'RO',
#       'JP',
#       'TV',
#       'HR',
#       'TD',
#       'HU',
#       'HT',
#       'WF',
#       'TL',
#       'MK',
#       'HK',
#       'WS',
#       'HN',
#       'HM',
#       'SJ',
#       'OM',
#       'UY',
#       'TT',
#       'AL',
#       'AM',
#       'TM',
#       'AO',
#       'TK',
#       'AI',
#       'IR',
#       'IS',
#       'AD',
#       'TF',
#       'AF',
#       'AG',
#       'TC',
#       'ID',
#       'IE',
#       'AX',
#       'TZ',
#       'AZ',
#       'IM',
#       'AT',
#       'AU',
#       'IN',
#       'AW',
#       'AQ',
#       'AR',
#       'AS',
#       'IO',
#       'LC',
#       'LB',
#       'LA',
#       'UA',
#       'LK',
#       'LI',
#       'TR',
#       'LV',
#       'LU',
#       'LT',
#       'LS',
#       'LR',
#       'LY',
#       'BE',
#       'BD',
#       'BG',
#       'BF',
#       'BA',
#       'BB',
#       'BM',
#       'BL',
#       'BO',
#       'BN',
#       'BI',
#       'BH',
#       'BJ',
#       'YT',
#       'BT',
#       'BW',
#       'BV',
#       'BQ',
#       'BS',
#       'BR',
#       'BY',
#       'BZ',
#       'UM',
#       'QA',
#       'SA']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '428727',
#     'likeCount': '2181',
#     'dislikeCount': '43',
#     'favoriteCount': '0',
#     'commentCount': '106'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf', '/m/04rlf'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Music']}},
#   {'kind': 'youtube#video',
#    'etag': 'H5CfkaXnY5_5gjhmQttA6kZkiq4',
#    'id': '6kiGXFDijUI',
#    'snippet': {'publishedAt': '2013-11-20T18:38:27Z',
#     'channelId': 'UCqsEcqpXUrq9YUt0bRgp9Og',
#     'title': 'Moriarty - Jimmy (Nu&Ky Bootleg)',
#     'description': 'Lluvia Magnética - Enjoy the music while it rains.\nFacebook: https://www.facebook.com/LluviaMagnetica\n\n♪ Free Download:\nhttps://soundcloud.com/nu-ky/nu-ky-jimmy-bootleg-free-1\n\n♪ Artist: Nu&Ky\nhttps://www.facebook.com/pages/NuKy/172186256314705 \nhttps://soundcloud.com/nu-ky\n\n♪ Artist: Moriarty\nhttp://moriartyland.net/\n\n♪ Image:\nhttp://500px.com/photo/24035899\nhttp://500px.com/peterholmeiii\n\n© Please contact  lluviamagnetica@gmail.com for any claim or video removal requests (producers, labels and artists).',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6kiGXFDijUI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6kiGXFDijUI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6kiGXFDijUI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/6kiGXFDijUI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/6kiGXFDijUI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Lluvia Magnética',
#     'tags': ['Uplifting',
#      'electronic',
#      'Lluvia',
#      'Magnetica',
#      'Moriarty Jimmy Nu&Ky Bootleg',
#      'rain',
#      'country',
#      'ride',
#      'driving music',
#      'guitar',
#      'clasical',
#      'hermonica'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Moriarty - Jimmy (Nu&Ky Bootleg)',
#      'description': 'Lluvia Magnética - Enjoy the music while it rains.\nFacebook: https://www.facebook.com/LluviaMagnetica\n\n♪ Free Download:\nhttps://soundcloud.com/nu-ky/nu-ky-jimmy-bootleg-free-1\n\n♪ Artist: Nu&Ky\nhttps://www.facebook.com/pages/NuKy/172186256314705 \nhttps://soundcloud.com/nu-ky\n\n♪ Artist: Moriarty\nhttp://moriartyland.net/\n\n♪ Image:\nhttp://500px.com/photo/24035899\nhttp://500px.com/peterholmeiii\n\n© Please contact  lluviamagnetica@gmail.com for any claim or video removal requests (producers, labels and artists).'}},
#    'contentDetails': {'duration': 'PT5M6S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '1677',
#     'likeCount': '20',
#     'dislikeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '1'},
#    'topicDetails': {'relevantTopicIds': ['/m/04rlf',
#      '/m/05rwpb',
#      '/m/04rlf',
#      '/m/05rwpb'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Independent_music',
#      'https://en.wikipedia.org/wiki/Music']}}],
#  'pageInfo': {'totalResults': 38, 'resultsPerPage': 38}}

# %%
# TODO: dumps the `result` in a JSON string, `json_result`
### BEGIN STRIP ###
json_result = json.dumps(result)
### END STRIP ###

# %% [markdown]
# ## 3. Store the data in S3
#
# We now have a JSON string containing extra data from 5000 videos. We now need to store this data in S3, in order to make it available for future computations.
#
# You are going to store the data under the key `youtube/{{ your-name }}/songs.json`.
#
# For instance, if you are George Abitbol, first, whoooaaa 😳, then your storage key is `youtube/george-abitbol/songs.json`.
#
# #### Reminder
#
# You probably need the `boto3` [documentation](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html#bucket) related to S3 buckets.
#
# To put your AWS credentials directly in our s3 object, we recommend using a `boto3.Session()` object. Check out [this page](https://boto3.amazonaws.com/v1/documentation/api/latest/guide/session.html) for a quick explanation.

# %%
import os
import logging

import boto3

# Avoid DEBUG messages from Boto3. You don't have to understand ;-)
logging.getLogger('botocore').setLevel(logging.INFO)
logging.getLogger('boto3').setLevel(logging.INFO)

# %%
# TODO: set up your AWS credentials
# NOTE: This is NOT how you should do that in the real world...
ACCESS_KEY_ID = 'YOUR_ACCESS_KEY'
SECRET_ACCESS_KEY = 'YOUR_SECRET_ACCESS_KEY'

# TODO: create a `boto3.Session` object containing your AWS credentials
### BEGIN STRIP ###
session = boto3.Session(
    region_name='eu-west-3',  # Datacenters located in Paris, FR
    aws_access_key_id=ACCESS_KEY_ID, 
    aws_secret_access_key=SECRET_ACCESS_KEY
)
### END STRIP ###

# %%
# TODO: create an `s3` resource object
### BEGIN STRIP ###
s3 = session.resource('s3')
### END STRIP ###

# TODO: create the bucket object representing the bucket `jedha-cloud-storage`
### BEGIN STRIP ###
bucket = s3.Bucket('jedha-cloud-storage-157')
### END STRIP ###

# TODO: As you did in the previous exercice, store your `json_result` object under your own storage key
### BEGIN STRIP ###
bucket.put_object(
    ACL='private', 
    Body=json_result.encode(), # See docs: `Body` needs to be bytes
    Key='youtube/george-abitbol/songs.json'
)
### END STRIP ###
# Out:
# s3.Object(bucket_name='jedha-cloud-storage-157', key='youtube/george-abitbol/songs.json')

# %% [markdown]
# Depending on your Internet connection, this may take some time... Uploading data big amount of data in the Cloud is not free!

# %% [markdown]
# ---
#
# ## 4. Summing up
#
# In this exercice, you have learned:
# - How to read a public API documentation
# - The concept of concurrent programming, to improve performance
# - How to create a `boto3` session object to explicitely store your AWS credentials
# - How to upload a JSON data structure to S3
#
# Not too bad!
#
# ![travis](https://media.giphy.com/media/LYDNZAzOqrez6/giphy.gif)

# %% [markdown]
# ## 5. Extra resources
#
# About `asyncio` et asyncrhonous programming in Python:
#
# - [asyncio: A complete walkthrough](https://realpython.com/async-io-python/)
# - [Making 1 million requests with Python](https://pawelmhm.github.io/asyncio/python/aiohttp/2016/04/22/asyncio-aiohttp.html)
#
# About logging
#
# - [What is logging?](https://en.wikipedia.org/wiki/Log_file)
# - [Logging in Python](https://docs.python.org/3/library/logging.html)
